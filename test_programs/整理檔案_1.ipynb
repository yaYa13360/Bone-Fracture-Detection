# %%
import os
import csv

# %%
# 1, 2.
# =================================
## 雲端
# directory_path = "D://reaserch//data//bone_中榮//雲端//20230907 三踝骨折65個"
# directory_path = "D://reaserch//data//bone_中榮//雲端//20230907 正常組65個"
# directory_path = "D://reaserch//data//bone_中榮//雲端//20230907 雙踝骨折66個"

## folder
# directory_path = "D://reaserch//data//bone_中榮//folder//雙踝骨折30組"
# directory_path = "D://reaserch//data//bone_中榮//folder//正常組30個"
# directory_path = "D://reaserch//data//bone_中榮//folder//三踝骨折30組"

## 正常_三踝
# directory_path = "E://data_bone//正常_三踝//正常_三踝_clean//三踝骨折組"
# directory_path = "E://data_bone//正常_三踝//正常_三踝_clean//正常組"

## b-24資料
# directory_path = "E://data_bone//b-24資料//clean//三踝"
directory_path = "E://data_bone//b-24資料//clean//雙踝"
# =================================

# 2. type, 原始檔案存(_clean)，csv用來記錄病例狀況
# =================================
output_csv_path = '三踝.csv' 
# output_csv_path = '雙踝.csv' 
# output_csv_path = '正常.csv' 
# =================================


# 3. front, side儲存照片，新目錄 (_clean2)
# =================================
## 雲端
# directory_path_side = "E://data_bone//雲端//雲端_clean2//side//20230907 三踝骨折65個"
# directory_path_side = "E://data_bone//雲端//雲端_clean2//side//20230907 正常組65個"
# directory_path_side = "E://data_bone//雲端//雲端_clean2//side//20230907 雙踝骨折66個"
# ==
# directory_path_front = "E://data_bone//雲端//雲端_clean2//front//20230907 三踝骨折65個"
# directory_path_front = "E://data_bone//雲端//雲端_clean2//front//20230907 正常組65個"
# directory_path_front = "E://data_bone//雲端//雲端_clean2//front//20230907 雙踝骨折66個"

## folder
# directory_path_side = "E://data_bone//folder//folder_clean2//side//三踝骨折30組"
# directory_path_side = "E://data_bone//folder//folder_clean2//side//雙踝骨折30組"
# directory_path_side = "E://data_bone//folder//folder_clean2//side//正常組30組"
# ==
# directory_path_front = "E://data_bone//folder//folder_clean2//front//三踝骨折30組"
# directory_path_front = "E://data_bone//folder//folder_clean2//front//雙踝骨折30組"
# directory_path_front = "E://data_bone//folder//folder_clean2//front//正常組30組"

## 正常_三踝
# directory_path_side = "E://data_bone//正常_三踝//正常_三踝_clean2//side//三踝骨折組"
# directory_path_side = "E://data_bone//正常_三踝//正常_三踝_clean2//side//正常組"
# ==
# directory_path_front = "E://data_bone//正常_三踝//正常_三踝_clean2//front//三踝骨折組"
# directory_path_front = "E://data_bone//正常_三踝//正常_三踝_clean2//front//正常組"

## b-24資料
# directory_path_side = "E://data_bone//b-24資料//clean_2//side//三踝"
directory_path_side = "E://data_bone//b-24資料//clean_2//side//雙踝"
# ==
# directory_path_front = "E://data_bone//b-24資料//clean_2//front//三踝"
directory_path_front = "E://data_bone//b-24資料//clean_2//front//雙踝"
# =================================


# 4, 5 命名左右腳
# =================================
## 雲端
# path = ["E://data_bone//雲端//雲端_clean2//side//20230907 三踝骨折65個"
#         "E://data_bone//雲端//雲端_clean2//front//20230907 正常組65個"
#         "E://data_bone//雲端//雲端_clean2//front//20230907 三踝骨折65個"
#         "E://data_bone//雲端//雲端_clean2//side//20230907 雙踝骨折66個"
#         "E://data_bone//雲端//雲端_clean2//front//20230907 雙踝骨折66個"
#         "E://data_bone//雲端//雲端_clean2//side//20230907 正常組65個"
#         ]

## folder
# path = [
#         "E://data_bone//folder//folder_clean2//side//三踝骨折30組", 
#         "E://data_bone//folder//folder_clean2//front//三踝骨折30組",
#         "E://data_bone//folder//folder_clean2//side//雙踝骨折30組",  
#         "E://data_bone//folder//folder_clean2//front//雙踝骨折30組",   
#         "E://data_bone//folder//folder_clean2//side//正常組30個",  
#         "E://data_bone//folder//folder_clean2//front//正常組30個"
#        ]

## 正常_三踝
# path = [
#         "E://data_bone//正常_三踝//正常_三踝_clean2//side//三踝骨折組",  
#         "E://data_bone//正常_三踝//正常_三踝_clean2//front//三踝骨折組",
#         "E://data_bone//正常_三踝//正常_三踝_clean2//side//正常組",  
#         "E://data_bone//正常_三踝//正常_三踝_clean2//front//正常組"
#        ]

## b-24資料
path = [
        "E://data_bone//b-24資料//clean_2//front//三踝",  
        "E://data_bone//b-24資料//clean_2//front//雙踝",  
        "E://data_bone//b-24資料//clean_2//side//三踝",  
        "E://data_bone//b-24資料//clean_2//side//雙踝",  
       ]
# =================================


# 5, 6  寫(all.csv)
# =================================
output_csv_path_all = '雲端_all.csv' 
output_csv_path_all = 'folder_all.csv' 
output_csv_path_all = '正常_三踝_all.csv' 
output_csv_path_all = '24資料_all.csv' 
# =================================

## 6. 寫(all_clean.csv)
# =================================
# output_csv_path_all_clean = '雲端_all_clean.csv' 
# output_csv_path_all_clean = 'folder_all_clean.csv' 
# output_csv_path_all_clean = '正常_三踝_all_clean.csv' 
output_csv_path_all_clean = '24資料_all._clean.csv' 
# =================================

# %%
# 1. 改檔名
def rename_folder(directory_path):
    # 確認目錄是否存在
    if not os.path.isdir(directory_path):
        print(f"The directory {directory_path} does not exist.")
        return

    # 收集所有資料夾名稱
    directories = [name for name in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, name))]

    # 將資料夾名稱寫入CSV檔
    for directory in directories:
        old_path = os.path.join(directory_path, directory)
        try:
            ## 根據任務拆解
            #=================================
            # new_path = os.path.join(directory_path, directory.split(' - ')[1])
            new_path = os.path.join(directory_path, directory.split('(')[0])
            # new_path = os.path.join(directory_path, directory.split(' ')[0])
            # new_path = os.path.join(directory_path, directory.split('-')[0])
            # =================================
            os.rename(old_path, new_path)
        except Exception as e:
            None
    print(f"Successfully rename")
rename_folder(directory_path)
# Out:
# Successfully rename

# %%
# 2. 寫檔名(病歷號)
def list_directories_to_csv(directory_path, output_csv_path):
    # 確認目錄是否存在
    if not os.path.isdir(directory_path):
        print(f"The directory {directory_path} does not exist.")
        return

    # 收集所有資料夾名稱
    directories = [name for name in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, name))]

    # 將資料夾名稱寫入CSV檔
    with open(output_csv_path, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['uuid'])  # 寫入CSV標題
        for directory in directories:
            writer.writerow([directory])
    
    print(f"Successfully wrote directory names to {output_csv_path}")


list_directories_to_csv(directory_path, output_csv_path)
# Out:
# Successfully wrote directory names to 三踝.csv

# %%
## 3. 分front, side  檔案(先清front)
# walk side所有資料
def list_all_files(directory):
    # 確認目錄是否存在
    if not os.path.isdir(directory):
        print(f"The directory {directory} does not exist.")
        return

    # 列出所有文件
    all_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            all_files.append(os.path.join(root, file))

    return all_files

# 刪掉有在front的資料
def delete_file(file_path):
    try:
        # 檢查文件是否存在
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"File '{file_path}' has been deleted.")
        else:
            print(f"File '{file_path}' does not exist.")
    except Exception as e:
        print(f"Error deleting file '{file_path}': {e}")


files = list_all_files(directory_path_side)
files2 = list_all_files(directory_path_front)

for f in files2:
    tmp = f.replace("front", "side")
    if tmp in files:
        try:
            delete_file(tmp)
            print(tmp)
        except:
            None

# %%
## 4. 命名左右腳
import matplotlib.pyplot as plt
from PIL import Image
from IPython.dRisplay import clear_output
import os

ex = []
for p in path:
    
    for root, dirs, files in os.walk(p):
        for file in files:
            clear_output(wait=True)
            # 顯示照片
            img = Image.open(os.path.join(root, file))
            plt.imshow(img)
            plt.axis('off')
            print(os.path.join(root, file))
            plt.show()

            # rename: L: l, R: 2
            new_name = input("input:")
            try:
                os.rename(os.path.join(root, file), os.path.join(root, new_name+'.jpg'))
            except Exception as e:
                ex.append(os.path.join(root, file))

# %%
## 5. 整理all.csv
with open(output_csv_path_all, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['uuid', 'nor_bi_tri' ,'front_side', 'R_L'])
    for p in path:
        for root, dirs, files in os.walk(p):
            for file in files:
                type_tmp = ""
                if "正常組" in root.split("//")[-1]:
                    type_tmp = "nor"
                elif "三踝" in root.split("//")[-1]:
                    type_tmp = "tri"
                elif "雙踝" in root.split("//")[-1]:
                    type_tmp = "bi"
                else:
                    print(os.path.join(root, file))

                writer.writerow([root.split("\\")[-1], type_tmp, root.split("//")[4], file.replace(".jpg", "")])

print(f"Success")
# Out:
# Success

# %%
## 6. 整理all_clean.csv(照順序)
import pandas as pd
df = pd.read_csv(output_csv_path_all, encoding='utf-8')
df_new = df.sort_values(by=['nor_bi_tri', 'uuid', 'front_side','R_L'])
df_new.to_csv(output_csv_path_all_clean, index=False)
print(f"Success")

## 檢查空值
df_new.isnull().sum()
# Out:
# Success
# uuid          0
# nor_bi_tri    0
# front_side    0
# R_L           0
# dtype: int64

# %%
# 8. 統整all資料夾，病例不重複 all_nonrepeat.csv
path = [
        "E://data_bone//all//front//三踝",
        "E://data_bone//all//side//三踝",
        "E://data_bone//all//front//雙踝",   
        "E://data_bone//all//side//雙踝",  
        "E://data_bone//all//front//正常",
        "E://data_bone//all//side//正常"  
    ]

output_csv_path = 'all_nonrepeat.csv'

with open(output_csv_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['uuid', 'nor_bi_tri' ,'front_side', 'R_L'])
    for p in path:
        for root, dirs, files in os.walk(p):
            for file in files:
                type_tmp = ""
                if "正常" in root.split("//")[-1]:
                    type_tmp = "nor"
                elif "三踝" in root.split("//")[-1]:
                    type_tmp = "tri"
                elif "雙踝" in root.split("//")[-1]:
                    type_tmp = "bi"
                else:
                    print(os.path.join(root, file))

                writer.writerow([root.split("\\")[-1], type_tmp, root.split("//")[3], file.replace(".jpg", "")])

print(f"Success")

# %%
import pandas as pd
df_new = pd.read_csv("all_nonrepeat.csv", encoding='utf-8')
tmp_arr = ['nor', 'bi', 'tri']
# 總病例數確認
print("#總病例數確認")
for tmp in tmp_arr:
    print("\n"+tmp+":")
    print(len(df_new['uuid'][df_new['nor_bi_tri'] == tmp].unique()))
print()

# 總張數
print("#總張數")
for tmp in tmp_arr:
    print("\n"+tmp+":")
    print(len(df_new['uuid'][df_new['nor_bi_tri'] == tmp]))
print()

# front
print("#front")
for tmp in tmp_arr:
    print("\n"+tmp+":")
    print(len(df['uuid'][(df['nor_bi_tri'] == tmp) & (df['front_side'] == 'front')]))
print()

# side
print("#side")
for tmp in tmp_arr:
    print("\n"+tmp+":")
    print(len(df['uuid'][(df['nor_bi_tri'] == tmp) & (df['front_side'] == 'side')]))
# Out:
# #總病例數確認
#
# nor:
# 85
#
# bi:
# 72
#
# tri:
# 105
#
# #總張數
#
# nor:
# 321
#
# bi:
# 151
#
# tri:
# 215
#
# #front
#
# nor:
# 161
#
# bi:
# 75
#
# tri:
# 105
#
# #side
#
# nor:
# 160
#
# bi:
# 76
#
# tri:
# 110

# %%
def list_all_files(directory):
    # 確認目錄是否存在
    if not os.path.isdir(directory):
        print(f"The directory {directory} does not exist.")
        return

    # 列出所有文件
    all_files = []
    for root, dirs, files in os.walk(directory):
        for file in files:
            all_files.append(os.path.join(root, file))

    return all_files
directory_front = "E://data_bone//all//front//雙踝"
directory_side = "E://data_bone//all//side//雙踝"

tmp_front = list_all_files(directory_front)
tmp_side = list_all_files(directory_side)
for i in range (len(tmp_front)):
    front_rename = "front-"+tmp_front[i].split("\\")[-1]

for i in range (len(tmp_side)):
    side_rename = "side-"+tmp_side[i].split("\\")[-1]
# Out:
# 'front-R.jpg'
