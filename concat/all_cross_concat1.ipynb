# %%
# import
import numpy as np
import pandas as pd
import os.path
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from sklearn.metrics import f1_score, accuracy_score
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout
import math
from tensorflow.keras.models import Model

## label
# =========================
def class_2_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    else:
        label = "1"
    return label

def class_3_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    elif "雙踝" in root:
        label = "1"
    elif "三踝" in root:
        label = "2"
    return label
# =========================


def load_path(path, class_count):
    dataset = []
    class_type = ''
    if class_count == 2:
        class_type = class_2_type
    elif class_count == 3:
        class_type = class_3_type  

    for root, dirs, files in os.walk(path):
        for file in files:
            label = class_type(root)
            # if label != "":
            dataset.append(
                            {   
                                'uuid': root.split("\\")[-1],
                                'label': label,
                                'image_path': os.path.join(root, file)
                            }
                        )

    return dataset

def create_front_extract():
    pretrained_model_chosen = tf.keras.applications.resnet50.ResNet50
    pretrained_model = pretrained_model_chosen(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg')
    pretrained_model.trainable = False
    return pretrained_model

def create_side_extract():
    pretrained_model_chosen = tf.keras.applications.efficientnet.EfficientNetB0
    pretrained_model = pretrained_model_chosen(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg')
    pretrained_model.trainable = False
    return pretrained_model

def multi_input_generator(front_gen, side_gen):
    while True:
        front_batch, y1 = next(front_gen)
        side_batch, y2 = next(side_gen)
        assert (y1 == y2).all(), "Label mismatch!"  # 確保標籤一致
        yield ([front_batch, side_batch], y1)


# def train_cross_validation(image_dir, n_splits=5, class_count=2, maru_part=None,  chosen_model='resnet50'):
def train_cross_validation(image_dir, n_splits=5, class_count=2):


    ## load data and  labels
    # =========================
    labels = []
    filepaths = []
    data = load_path(image_dir, class_count)
    for row in data:
        labels.append(row['label'])
        filepaths.append(row['image_path'])

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    images = pd.concat([filepaths, labels], axis=1)
    # =========================

    ## split image
    # =========================
    train_df_front, test_df_front = train_test_split(images, train_size=0.8, shuffle=True, random_state=1, stratify=images['Label'])
    print("Training set label distribution:\n", train_df_front['Label'].value_counts(normalize=False))
    print("Test set label distribution:\n", test_df_front['Label'].value_counts(normalize=False))
    # =========================

    preprocessing_function_chosen_front = tf.keras.applications.resnet50.preprocess_input
    preprocessing_function_chosen_side = tf.keras.applications.efficientnet.preprocess_input


    ## train model, k fold cross validation
    # ==================================================
    fold_no = 1
    test_acc = []
    test_f1 = []

    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
    for train_index, val_index in kfold.split(train_df_front, train_df_front['Label']):
        k_fold_train_front = train_df_front.iloc[train_index]
        k_fold_val_front = train_df_front.iloc[val_index]

        # front images
        # =========================
        train_generator_front = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,
                                                                                preprocessing_function=preprocessing_function_chosen_front)
        test_generator_front = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen_front)

        train_images_front = train_generator_front.flow_from_dataframe(
            dataframe=k_fold_train_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        val_images_front = train_generator_front.flow_from_dataframe(
            dataframe=k_fold_val_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        test_images_front = test_generator_front.flow_from_dataframe(
            dataframe=test_df_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=32,
            shuffle=False
        )
        # =========================   

        # side images
        # =========================
        train_df_side = train_df_front.copy()
        test_df_side = test_df_front.copy()
        train_df_side.loc[:, "Filepath"] = train_df_front["Filepath"].str.replace("front", "side")
        test_df_side.loc[:, "Filepath"] = test_df_side["Filepath"].str.replace("front", "side")

        k_fold_train_side = train_df_side.iloc[train_index]
        k_fold_val_side = train_df_side.iloc[val_index]

        train_generator_side = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,
                                                                                preprocessing_function=preprocessing_function_chosen_side)
        test_generator_side = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen_side)

        train_images_side = train_generator_side.flow_from_dataframe(
            dataframe=k_fold_train_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        val_images_side = train_generator_side.flow_from_dataframe(
            dataframe=k_fold_val_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        test_images_side = test_generator_side.flow_from_dataframe(
            dataframe=test_df_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=32,
            shuffle=False
        )
        # ========================= 
        
        # load model
        # =========================
        # input 
        input_front = Input(shape=(224, 224, 3), name="AP(Mortise)")
        input_side = Input(shape=(224, 224, 3), name="Lateral")

        # model
        model_front = create_front_extract()
        model_side = create_side_extract()

        features_front = model_front(input_front)
        features_side = model_side(input_side)

        features_front_x = tf.keras.layers.Dense(128, activation='relu', name='AP_dense_128')(features_front)
        features_front_x = tf.keras.layers.Dense(50, activation='relu', name='AP_dense_50')(features_front_x)

        features_side_x = tf.keras.layers.Dense(128, activation='relu', name='Lateral_dense_128')(features_side)
        features_side_x = tf.keras.layers.Dense(50, activation='relu', name='Lateral_dense_50')(features_side_x)

        fused_features = Concatenate(name="feature_fusion")([features_front_x, features_side_x])
        # fused_features = tf.keras.layers.Dense(50, activation='relu', name='fusion_dense_50')(fused_features)
        fused_features = Dropout(0.1)(fused_features)

        final_output = Dense(class_count, activation='sigmoid', name='output_layer')(fused_features)
        multi_view_model = None
        multi_view_model = Model(
            inputs=[input_front, input_side],
            outputs=final_output
        )
        multi_view_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

        multi_view_model.summary()
        # print(model.summary())
        # =========================

        train_generator = multi_input_generator(train_images_front, train_images_side)
        val_generator = multi_input_generator(val_images_front, val_images_side)
        
        ## compile and evaluate
        # =========================

        print("-------Training_" + concat_type + "-------")
        multi_view_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
        
        batch_size = 64
        ## early stop 
        # early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
        # multi_view_model.fit(train_generator, validation_data=val_generator, callbacks=[early_stopping], epochs=30,
        #                             steps_per_epoch= math.ceil(train_images_front.samples / batch_size), 
        #                             validation_steps= math.ceil(val_images_front.samples / batch_size))
        ## no early stop
        multi_view_model.fit(train_generator, validation_data=val_generator, epochs=30,
                            steps_per_epoch= math.ceil(train_images_front.samples / batch_size), 
                            validation_steps= math.ceil(val_images_front.samples / batch_size))

        # =========================

        test_generator = multi_input_generator(test_images_front, test_images_side)
        batch_size=32
        pred = multi_view_model.predict(test_generator,  steps=math.ceil(test_images_front.samples / batch_size))
        predicted_labels = np.argmax(pred, axis=1)

        # =========================
            
        ## print results
        # =========================
        acc = accuracy_score(test_images_front.labels, predicted_labels)

        test_acc.append(np.round(acc, 2))
        f1 = f1_score(test_images_front.labels, predicted_labels, average='macro')
        test_f1.append(np.round(f1, 2))
        fold_no += 1
        # =========================
    # ==================================================
        
    ## print  mean results
    # =========================
    acc_mean  = np.round(np.mean(test_acc), 2)
    acc_std = np.round(np.std(test_acc), 2)
    f1_mean  = np.round(np.mean(test_f1), 2)
    f1_std = np.round(np.std(test_f1), 2)
    # print(f"acc mean = {acc_mean}, std = {acc_std}")
    # print(test_acc)
    # print(f"f1  mean = {f1_mean}, std = {f1_std}")
    # print(test_f1)
    # =========================

    return {'acc_mean':acc_mean, 'acc_std':acc_std, 'test_acc':test_acc, 'f1_mean':f1_mean, 'f1_std':f1_std, 'test_f1':test_f1}


path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\front"

concat_type = "concat1"


# =========================




results = []
results = train_cross_validation(image_dir=path, class_count=3)


print(f"acc mean = {results['acc_mean']}, std = {results['acc_std']}, test_acc = {results['test_acc']}")
print(f"f1  mean = {results['f1_mean']}, std = {results['f1_std']}, test_f1 = {results['test_f1']}")
# Out:
# Training set label distribution:
#  0    128
# 2     95
# 1     93
# Name: Label, dtype: int64
# Test set label distribution:
#  0    32
# 1    24
# 2    24
# Name: Label, dtype: int64
# Found 252 validated image filenames belonging to 3 classes.
# Found 64 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 252 validated image filenames belonging to 3 classes.
# Found 64 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None,
# 4/4 [==============================] - 2s 679ms/step - loss: 0.3288 - accuracy: 0.9206 - val_loss: 0.4650 - val_accuracy: 0.8281
# Epoch 22/30
# 4/4 [==============================] - 2s 577ms/step - loss: 0.3352 - accuracy: 0.9087 - val_loss: 0.4585 - val_accuracy: 0.8281
# Epoch 23/30
# 4/4 [==============================] - 2s 582ms/step - loss: 0.3364 - accuracy: 0.9167 - val_loss: 0.4541 - val_accuracy: 0.8281
# Epoch 24/30
# 4/4 [==============================] - 2s 574ms/step - loss: 0.3274 - accuracy: 0.8968 - val_loss: 0.4511 - val_accuracy: 0.8281
# Epoch 25/30
# 4/4 [==============================] - 2s 575ms/step - loss: 0.3107 - accuracy: 0.9167 - val_loss: 0.4489 - val_accuracy: 0.8281
# Epoch 26/30
# 4/4 [==============================] - 2s 568ms/step - loss: 0.2782 - accuracy: 0.9484 - val_loss: 0.4455 - val_accuracy: 0.8281
# Epoch 27/30
# 4/4 [==============================] - 2s 571ms/step - loss: 0.3008 - accuracy: 0.9286 - val_loss: 0.4409 - val_accuracy: 0.8281
# Epoch 28/30
# 4/4 [==============================] - 2s 579ms/step - loss: 0.2624 - accuracy: 0.9405 - val_loss: 0.4388 - val_accuracy: 0.8281
# Epoch 29/30
# 4/4 [==============================] - 2s 588ms/step - loss: 0.2573 - accuracy: 0.9405 - val_loss: 0.4371 - val_accuracy: 0.8281
# Epoch 30/30
# 4/4 [==============================] - 2s 588ms/step - loss: 0.2558 - accuracy: 0.9405 - val_loss: 0.4334 - val_accuracy: 0.8281
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_1[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 8s 1s/step - loss: 1.2406 - accuracy: 0.3478 - val_loss: 1.0578 - val_accuracy: 0.4921
# Epoch 2/30
# 4/4 [==============================] - 2s 584ms/step - loss: 1.0498 - accuracy: 0.4743 - val_loss: 0.9790 - val_accuracy: 0.4603
# Epoch 3/30
# 4/4 [==============================] - 2s 587ms/step - loss: 0.9686 - accuracy: 0.5375 - val_loss: 0.8462 - val_accuracy: 0.7302
# Epoch 4/30
# Epoch 24/30
# 4/4 [==============================] - 2s 584ms/step - loss: 0.3259 - accuracy: 0.9051 - val_loss: 0.5265 - val_accuracy: 0.6984
# Epoch 25/30
# 4/4 [==============================] - 2s 581ms/step - loss: 0.2843 - accuracy: 0.9328 - val_loss: 0.5230 - val_accuracy: 0.7143
# Epoch 26/30
# 4/4 [==============================] - 2s 574ms/step - loss: 0.2739 - accuracy: 0.9130 - val_loss: 0.5210 - val_accuracy: 0.7143
# Epoch 27/30
# 4/4 [==============================] - 2s 574ms/step - loss: 0.2543 - accuracy: 0.9526 - val_loss: 0.5179 - val_accuracy: 0.7143
# Epoch 28/30
# 4/4 [==============================] - 2s 587ms/step - loss: 0.2586 - accuracy: 0.9328 - val_loss: 0.5180 - val_accuracy: 0.7302
# Epoch 29/30
# 4/4 [==============================] - 2s 583ms/step - loss: 0.2503 - accuracy: 0.9447 - val_loss: 0.5154 - val_accuracy: 0.7302
# Epoch 30/30
# 4/4 [==============================] - 2s 578ms/step - loss: 0.2347 - accuracy: 0.9644 - val_loss: 0.5134 - val_accuracy: 0.7302
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_2[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 6s 842ms/step - loss: 1.1923 - accuracy: 0.3439 - val_loss: 0.9895 - val_accuracy: 0.5556
# Epoch 2/30
# 4/4 [==============================] - 2s 622ms/step - loss: 1.0184 - accuracy: 0.5494 - val_loss: 0.9331 - val_accuracy: 0.5397
# Epoch 3/30
# 4/4 [==============================] - 2s 585ms/step - loss: 0.9219 - accuracy: 0.5771 - val_loss: 0.8587 - val_accuracy: 0.6190
# Epoch 4/30
# 4/4 [==============================] - 2s 585ms/step - loss: 0.8442 - accuracy: 0.6561 - val_loss: 0.7979 - val_accuracy: 0.7143
# Epoch 5/30
# 4/4 [==============================] - 2s 591ms/step - loss: 0.7761 - accuracy: 0.7075 - val_loss: 0.7482 - val_accuracy: 0.6984
# Epoch 6/30
# 4/4 [==============================] - 2s 590ms/step - loss: 0.7288 - accuracy: 0.7273 - val_loss: 0.7021 - val_accuracy: 0.6984
# Epoch 7/30
# Epoch 27/30
# 4/4 [==============================] - 2s 594ms/step - loss: 0.3296 - accuracy: 0.9130 - val_loss: 0.4507 - val_accuracy: 0.7778
# Epoch 28/30
# 4/4 [==============================] - 2s 586ms/step - loss: 0.3194 - accuracy: 0.9091 - val_loss: 0.4467 - val_accuracy: 0.7937
# Epoch 29/30
# 4/4 [==============================] - 2s 585ms/step - loss: 0.3166 - accuracy: 0.9170 - val_loss: 0.4446 - val_accuracy: 0.7778
# Epoch 30/30
# 4/4 [==============================] - 2s 584ms/step - loss: 0.2877 - accuracy: 0.9249 - val_loss: 0.4414 - val_accuracy: 0.7937
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_3[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 6s 901ms/step - loss: 1.1507 - accuracy: 0.3478 - val_loss: 1.0133 - val_accuracy: 0.4127
# Epoch 2/30
# 4/4 [==============================] - 2s 627ms/step - loss: 1.0151 - accuracy: 0.4980 - val_loss: 0.9170 - val_accuracy: 0.6190
# Epoch 3/30
# 4/4 [==============================] - 2s 601ms/step - loss: 0.9203 - accuracy: 0.5929 - val_loss: 0.8432 - val_accuracy: 0.6190
# Epoch 4/30
# 4/4 [==============================] - 2s 594ms/step - loss: 0.8433 - accuracy: 0.6482 - val_loss: 0.7815 - val_accuracy: 0.6667
# Epoch 5/30
# 4/4 [==============================] - 2s 593ms/step - loss: 0.7822 - accuracy: 0.6561 - val_loss: 0.7257 - val_accuracy: 0.6825
# Epoch 6/30
# 4/4 [==============================] - 2s 593ms/step - loss: 0.7138 - accuracy: 0.7036 - val_loss: 0.6843 - val_accuracy: 0.6825
# Epoch 7/30
# 4/4 [==============================] - 2s 601ms/step - loss: 0.6595 - accuracy: 0.7352 - val_loss: 0.6529 - val_accuracy: 0.6825
# Epoch 8/30
# 4/4 [==============================] - 2s 587ms/step - loss: 0.6070 - accuracy: 0.7826 - val_loss: 0.6292 - val_accuracy: 0.6508
# Epoch 9/30
# 4/4 [==============================] - 2s 589ms/step - loss: 0.5775 - accuracy: 0.7866 - val_loss: 0.6031 - val_accuracy: 0.6825
validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_4[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 6s 873ms/step - loss: 1.1440 - accuracy: 0.3715 - val_loss: 1.0688 - val_accuracy: 0.3968
# Epoch 2/30
# 4/4 [==============================] - 2s 641ms/step - loss: 1.0080 - accuracy: 0.5217 - val_loss: 0.9769 - val_accuracy: 0.5714
# Epoch 3/30
# 4/4 [==============================] - 2s 600ms/step - loss: 0.9008 - accuracy: 0.6285 - val_loss: 0.9075 - val_accuracy: 0.5556
# Epoch 4/30
# 4/4 [==============================] - 2s 601ms/step - loss: 0.8493 - accuracy: 0.6640 - val_loss: 0.8554 - val_accuracy: 0.5714
# Epoch 5/30
# 4/4 [==============================] - 2s 601ms/step - loss: 0.7618 - accuracy: 0.6719 - val_loss: 0.8059 - val_accuracy: 0.6667
# Epoch 6/30
# 4/4 [==============================] - 2s 606ms/step - loss: 0.7277 - accuracy: 0.7036 - val_loss: 0.7671 - val_accuracy: 0.6032
# Epoch 7/30
# 4/4 [==============================] - 2s 602ms/step - loss: 0.6598 - accuracy: 0.7549 - val_loss: 0.7350 - val_accuracy: 0.6349
# Epoch 8/30
# 4/4 [==============================] - 2s 605ms/step - loss: 0.6404 - accuracy: 0.7312 - val_loss: 0.7087 - val_accuracy: 0.6349
# Epoch 9/30
# 4/4 [==============================] - 2s 594ms/step - loss: 0.5776 - accuracy: 0.7945 - val_loss: 0.6855 - val_accuracy: 0.6667
# Epoch 10/30
# 4/4 [==============================] - 2s 606ms/step - loss: 0.5653 - accuracy: 0.7866 - val_loss: 0.6662 - val_accuracy: 0.6667
# Epoch 11/30
# 4/4 [==============================] - 2s 602ms/step - loss: 0.5468 - accuracy: 0.8221 - val_loss: 0.6498 - val_accuracy: 0.6984
# Epoch 12/30
# 4/4 [==============================] - 2s 613ms/step - loss: 0.5155 - accuracy: 0.8142 - val_loss: 0.6313 - val_accuracy: 0.6984
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from sklearn.metrics import f1_score, accuracy_score
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout
import math
from tensorflow.keras.models import Model

## label
# =========================
def class_2_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    else:
        label = "1"
    return label

def class_3_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    elif "雙踝" in root:
        label = "1"
    elif "三踝" in root:
        label = "2"
    return label
# =========================


def load_path(path, class_count):
    dataset = []
    class_type = ''
    if class_count == 2:
        class_type = class_2_type
    elif class_count == 3:
        class_type = class_3_type  

    for root, dirs, files in os.walk(path):
        for file in files:
            label = class_type(root)
            # if label != "":
            dataset.append(
                            {   
                                'uuid': root.split("\\")[-1],
                                'label': label,
                                'image_path': os.path.join(root, file)
                            }
                        )

    return dataset

def create_front_extract():
    pretrained_model_chosen = tf.keras.applications.resnet50.ResNet50
    pretrained_model = pretrained_model_chosen(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg')
    pretrained_model.trainable = False
    return pretrained_model

def create_side_extract():
    pretrained_model_chosen = tf.keras.applications.efficientnet.EfficientNetB0
    pretrained_model = pretrained_model_chosen(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg')
    pretrained_model.trainable = False
    return pretrained_model

def multi_input_generator(front_gen, side_gen):
    while True:
        front_batch, y1 = next(front_gen)
        side_batch, y2 = next(side_gen)
        assert (y1 == y2).all(), "Label mismatch!"  # 確保標籤一致
        yield ([front_batch, side_batch], y1)


# def train_cross_validation(image_dir, n_splits=5, class_count=2, maru_part=None,  chosen_model='resnet50'):
def train_cross_validation(image_dir, n_splits=5, class_count=2):


    ## load data and  labels
    # =========================
    labels = []
    filepaths = []
    data = load_path(image_dir, class_count)
    for row in data:
        labels.append(row['label'])
        filepaths.append(row['image_path'])

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    images = pd.concat([filepaths, labels], axis=1)
    # =========================

    ## split image
    # =========================
    train_df_front, test_df_front = train_test_split(images, train_size=0.8, shuffle=True, random_state=1, stratify=images['Label'])
    print("Training set label distribution:\n", train_df_front['Label'].value_counts(normalize=False))
    print("Test set label distribution:\n", test_df_front['Label'].value_counts(normalize=False))
    # =========================

    preprocessing_function_chosen_front = tf.keras.applications.resnet50.preprocess_input
    preprocessing_function_chosen_side = tf.keras.applications.efficientnet.preprocess_input


    ## train model, k fold cross validation
    # ==================================================
    fold_no = 1
    test_acc = []
    test_f1 = []

    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
    for train_index, val_index in kfold.split(train_df_front, train_df_front['Label']):
        k_fold_train_front = train_df_front.iloc[train_index]
        k_fold_val_front = train_df_front.iloc[val_index]

        # front images
        # =========================
        train_generator_front = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,
                                                                                preprocessing_function=preprocessing_function_chosen_front)
        test_generator_front = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen_front)

        train_images_front = train_generator_front.flow_from_dataframe(
            dataframe=k_fold_train_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        val_images_front = train_generator_front.flow_from_dataframe(
            dataframe=k_fold_val_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        test_images_front = test_generator_front.flow_from_dataframe(
            dataframe=test_df_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=32,
            shuffle=False
        )
        # =========================   

        # side images
        # =========================
        train_df_side = train_df_front.copy()
        test_df_side = test_df_front.copy()
        train_df_side.loc[:, "Filepath"] = train_df_front["Filepath"].str.replace("front", "side")
        test_df_side.loc[:, "Filepath"] = test_df_side["Filepath"].str.replace("front", "side")

        k_fold_train_side = train_df_side.iloc[train_index]
        k_fold_val_side = train_df_side.iloc[val_index]

        train_generator_side = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,
                                                                                preprocessing_function=preprocessing_function_chosen_side)
        test_generator_side = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen_side)

        train_images_side = train_generator_side.flow_from_dataframe(
            dataframe=k_fold_train_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        val_images_side = train_generator_side.flow_from_dataframe(
            dataframe=k_fold_val_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        test_images_side = test_generator_side.flow_from_dataframe(
            dataframe=test_df_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=32,
            shuffle=False
        )
        # ========================= 
        
        # load model
        # =========================
        # input 
        input_front = Input(shape=(224, 224, 3), name="AP(Mortise)")
        input_side = Input(shape=(224, 224, 3), name="Lateral")

        # model
        model_front = create_front_extract()
        model_side = create_side_extract()

        features_front = model_front(input_front)
        features_side = model_side(input_side)

        features_front_x = tf.keras.layers.Dense(128, activation='relu', name='AP_dense_128')(features_front)
        features_front_x = tf.keras.layers.Dense(50, activation='relu', name='AP_dense_50')(features_front_x)

        features_side_x = tf.keras.layers.Dense(128, activation='relu', name='Lateral_dense_128')(features_side)
        features_side_x = tf.keras.layers.Dense(50, activation='relu', name='Lateral_dense_50')(features_side_x)

        fused_features = Concatenate(name="feature_fusion")([features_front_x, features_side_x])
        # fused_features = tf.keras.layers.Dense(50, activation='relu', name='fusion_dense_50')(fused_features)
        fused_features = Dropout(0.1)(fused_features)

        final_output = Dense(class_count, activation='sigmoid', name='output_layer')(fused_features)
        multi_view_model = None
        multi_view_model = Model(
            inputs=[input_front, input_side],
            outputs=final_output
        )
        multi_view_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

        multi_view_model.summary()
        # print(model.summary())
        # =========================

        train_generator = multi_input_generator(train_images_front, train_images_side)
        val_generator = multi_input_generator(val_images_front, val_images_side)
        
        ## compile and evaluate
        # =========================

        print("-------Training_" + concat_type + "-------")
        multi_view_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
        
        batch_size = 64
        ## early stop 
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
        multi_view_model.fit(train_generator, validation_data=val_generator, callbacks=[early_stopping], epochs=30,
                                    steps_per_epoch= math.ceil(train_images_front.samples / batch_size), 
                                    validation_steps= math.ceil(val_images_front.samples / batch_size))
        ## no early stop
        # multi_view_model.fit(train_generator, validation_data=val_generator, epochs=30,
        #                     steps_per_epoch= math.ceil(train_images_front.samples / batch_size), 
        #                     validation_steps= math.ceil(val_images_front.samples / batch_size))

        # =========================

        test_generator = multi_input_generator(test_images_front, test_images_side)
        batch_size=32
        pred = multi_view_model.predict(test_generator,  steps=math.ceil(test_images_front.samples / batch_size))
        predicted_labels = np.argmax(pred, axis=1)

        # =========================
            
        ## print results
        # =========================
        acc = accuracy_score(test_images_front.labels, predicted_labels)

        test_acc.append(np.round(acc, 2))
        f1 = f1_score(test_images_front.labels, predicted_labels, average='macro')
        test_f1.append(np.round(f1, 2))
        fold_no += 1
        # =========================
    # ==================================================
        
    ## print  mean results
    # =========================
    acc_mean  = np.round(np.mean(test_acc), 2)
    acc_std = np.round(np.std(test_acc), 2)
    f1_mean  = np.round(np.mean(test_f1), 2)
    f1_std = np.round(np.std(test_f1), 2)
    # print(f"acc mean = {acc_mean}, std = {acc_std}")
    # print(test_acc)
    # print(f"f1  mean = {f1_mean}, std = {f1_std}")
    # print(test_f1)
    # =========================

    return {'acc_mean':acc_mean, 'acc_std':acc_std, 'test_acc':test_acc, 'f1_mean':f1_mean, 'f1_std':f1_std, 'test_f1':test_f1}


path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\front"

concat_type = "concat1"


# =========================




results = []
results = train_cross_validation(image_dir=path, class_count=3)


print(f"acc mean = {results['acc_mean']}, std = {results['acc_std']}, test_acc = {results['test_acc']}")
print(f"f1  mean = {results['f1_mean']}, std = {results['f1_std']}, test_f1 = {results['test_f1']}")
# Out:
# Training set label distribution:
#  0    128
# 2     95
# 1     93
# Name: Label, dtype: int64
# Test set label distribution:
#  0    32
# 1    24
# 2    24
# Name: Label, dtype: int64
# Found 252 validated image filenames belonging to 3 classes.
# Found 64 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 252 validated image filenames belonging to 3 classes.
# Found 64 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None,
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000259FA330048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_6[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 8s 1s/step - loss: 1.0420 - accuracy: 0.4783 - val_loss: 0.9290 - val_accuracy: 0.6825
# Epoch 2/30
# 4/4 [==============================] - 2s 751ms/step - loss: 0.9096 - accuracy: 0.6087 - val_loss: 0.8331 - val_accuracy: 0.7143
# Epoch 3/30
# 4/4 [==============================] - 2s 787ms/step - loss: 0.7993 - accuracy: 0.6522 - val_loss: 0.7661 - val_accuracy: 0.6984
# Epoch 4/30
# 4/4 [==============================] - 2s 716ms/step - loss: 0.7353 - accuracy: 0.6877 - val_loss: 0.7153 - val_accuracy: 0.6984
# Epoch 5/30
# 4/4 [==============================] - 2s 733ms/step - loss: 0.6588 - accuracy: 0.7154 - val_loss: 0.6799 - val_accuracy: 0.6667
# Epoch 6/30
# 4/4 [==============================] - 2s 742ms/step - loss: 0.6230 - accuracy: 0.7391 - val_loss: 0.6511 - val_accuracy: 0.6984
# Epoch 7/30
# 4/4 [==============================] - 2s 700ms/step - loss: 0.5546 - accuracy: 0.7945 - val_loss: 0.6302 - val_accuracy: 0.7143
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_7"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_7[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 7s 999ms/step - loss: 1.2383 - accuracy: 0.3913 - val_loss: 1.0940 - val_accuracy: 0.4603
# Epoch 2/30
# 4/4 [==============================] - 2s 621ms/step - loss: 1.0465 - accuracy: 0.4862 - val_loss: 0.9949 - val_accuracy: 0.5238
# Epoch 3/30
# 4/4 [==============================] - 2s 625ms/step - loss: 0.9922 - accuracy: 0.5494 - val_loss: 0.9072 - val_accuracy: 0.6667
# Epoch 4/30
# 4/4 [==============================] - 2s 638ms/step - loss: 0.8933 - accuracy: 0.6443 - val_loss: 0.8361 - val_accuracy: 0.6667
# Epoch 5/30
# 4/4 [==============================] - 2s 650ms/step - loss: 0.8044 - accuracy: 0.6719 - val_loss: 0.7836 - val_accuracy: 0.6667
# Epoch 6/30
# 4/4 [==============================] - 2s 785ms/step - loss: 0.7442 - accuracy: 0.7075 - val_loss: 0.7257 - val_accuracy: 0.7460
# Epoch 7/30
# 4/4 [==============================] - 2s 782ms/step - loss: 0.6840 - accuracy: 0.7273 - val_loss: 0.6795 - val_accuracy: 0.7460
# Epoch 8/30
# 4/4 [==============================] - 2s 783ms/step - loss: 0.6501 - accuracy: 0.7391 - val_loss: 0.6429 - val_accuracy: 0.7460
# Epoch 9/30
# 4/4 [==============================] - 2s 769ms/step - loss: 0.5954 - accuracy: 0.7787 - val_loss: 0.6148 - val_accuracy: 0.7778
# Epoch 10/30
# 4/4 [==============================] - 2s 783ms/step - loss: 0.5840 - accuracy: 0.7787 - val_loss: 0.5948 - val_accuracy: 0.7778
# Epoch 11/30
# 4/4 [==============================] - 2s 763ms/step - loss: 0.5377 - accuracy: 0.8063 - val_loss: 0.5762 - val_accuracy: 0.7778
# Epoch 12/30
# 4/4 [==============================] - 2s 764ms/step - loss: 0.5210 - accuracy: 0.8103 - val_loss: 0.5588 - val_accuracy: 0.7778
# Epoch 13/30
# 4/4 [==============================] - 2s 725ms/step - loss: 0.4917 - accuracy: 0.8142 - val_loss: 0.5448 - val_accuracy: 0.7619
# Epoch 14/30
# 4/4 [==============================] - 3s 807ms/step - loss: 0.4759 - accuracy: 0.8221 - val_loss: 0.5350 - val_accuracy: 0.7619
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_8[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 9s 1s/step - loss: 1.0424 - accuracy: 0.5217 - val_loss: 0.9460 - val_accuracy: 0.5873
# Epoch 2/30
# 4/4 [==============================] - 3s 801ms/step - loss: 0.9247 - accuracy: 0.5692 - val_loss: 0.8629 - val_accuracy: 0.6508
# Epoch 3/30
# 4/4 [==============================] - 3s 825ms/step - loss: 0.8212 - accuracy: 0.6838 - val_loss: 0.8134 - val_accuracy: 0.6825
# Epoch 4/30
# 4/4 [==============================] - 2s 765ms/step - loss: 0.7524 - accuracy: 0.6917 - val_loss: 0.7658 - val_accuracy: 0.6825
# Epoch 5/30
# 4/4 [==============================] - 3s 792ms/step - loss: 0.6959 - accuracy: 0.7312 - val_loss: 0.7198 - val_accuracy: 0.6825
# Epoch 6/30
# 4/4 [==============================] - 2s 749ms/step - loss: 0.6308 - accuracy: 0.7628 - val_loss: 0.6922 - val_accuracy: 0.7143
# Epoch 7/30
# 4/4 [==============================] - 2s 742ms/step - loss: 0.6123 - accuracy: 0.7589 - val_loss: 0.6639 - val_accuracy: 0.6984
# Epoch 8/30
# 4/4 [==============================] - 2s 770ms/step - loss: 0.5512 - accuracy: 0.7747 - val_loss: 0.6436 - val_accuracy: 0.7302
# Epoch 9/30
# 4/4 [==============================] - 2s 733ms/step - loss: 0.5456 - accuracy: 0.7787 - val_loss: 0.6372 - val_accuracy: 0.7143
# Epoch 10/30
# 4/4 [==============================] - 3s 792ms/step - loss: 0.5024 - accuracy: 0.7866 - val_loss: 0.6187 - val_accuracy: 0.7460
# Epoch 11/30
# 4/4 [==============================] - 2s 748ms/step - loss: 0.4645 - accuracy: 0.8300 - val_loss: 0.6026 - val_accuracy: 0.7302
# Epoch 12/30
# 4/4 [==============================] - 2s 765ms/step - loss: 0.4554 - accuracy: 0.8498 - val_loss: 0.5935 - val_accuracy: 0.7143
# Epoch 13/30
# 4/4 [==============================] - 2s 778ms/step - loss: 0.4406 - accuracy: 0.8458 - val_loss: 0.5884 - val_accuracy: 0.7143
# Epoch 14/30
# 4/4 [==============================] - 2s 698ms/step - loss: 0.4213 - accuracy: 0.8617 - val_loss: 0.5755 - val_accuracy: 0.6984
# Epoch 15/30
# 4/4 [==============================] - 2s 736ms/step - loss: 0.3861 - accuracy: 0.9012 - val_loss: 0.5682 - val_accuracy: 0.7143
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_9[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 8s 1s/step - loss: 1.2289 - accuracy: 0.3083 - val_loss: 1.0825 - val_accuracy: 0.4921
# Epoch 2/30
# 4/4 [==============================] - 2s 755ms/step - loss: 1.0149 - accuracy: 0.4980 - val_loss: 0.9771 - val_accuracy: 0.4286
# Epoch 3/30
# 4/4 [==============================] - 2s 757ms/step - loss: 0.8913 - accuracy: 0.6126 - val_loss: 0.8715 - val_accuracy: 0.6667
# Epoch 4/30
# 4/4 [==============================] - 2s 629ms/step - loss: 0.8056 - accuracy: 0.6482 - val_loss: 0.7994 - val_accuracy: 0.7143
# Epoch 5/30
# 4/4 [==============================] - 2s 630ms/step - loss: 0.7157 - accuracy: 0.7549 - val_loss: 0.7505 - val_accuracy: 0.6825
# Epoch 6/30
# 4/4 [==============================] - 2s 621ms/step - loss: 0.6736 - accuracy: 0.7510 - val_loss: 0.7135 - val_accuracy: 0.6508
# Epoch 7/30
# 4/4 [==============================] - 2s 628ms/step - loss: 0.6328 - accuracy: 0.7391 - val_loss: 0.6752 - val_accuracy: 0.6667
# Epoch 8/30
# 4/4 [==============================] - 2s 630ms/step - loss: 0.5807 - accuracy: 0.7628 - val_loss: 0.6448 - val_accuracy: 0.6667
# Epoch 9/30
# 4/4 [==============================] - 2s 617ms/step - loss: 0.5484 - accuracy: 0.7747 - val_loss: 0.6214 - val_accuracy: 0.6667
# acc mean = 0.73, std = 0.06, test_acc = [0.76, 0.64, 0.7, 0.8, 0.75]
# f1  mean = 0.7, std = 0.06, test_f1 = [0.73, 0.6, 0.66, 0.78, 0.72]

# %%
# import
import numpy as np
import pandas as pd
import os.path
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
import os
from sklearn.metrics import f1_score, accuracy_score
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout
import math
from tensorflow.keras.models import Model

## label
# =========================
def class_2_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    else:
        label = "1"
    return label

def class_3_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    elif "雙踝" in root:
        label = "1"
    elif "三踝" in root:
        label = "2"
    return label
# =========================


def load_path(path, class_count):
    dataset = []
    class_type = ''
    if class_count == 2:
        class_type = class_2_type
    elif class_count == 3:
        class_type = class_3_type  

    for root, dirs, files in os.walk(path):
        for file in files:
            label = class_type(root)
            # if label != "":
            dataset.append(
                            {   
                                'uuid': root.split("\\")[-1],
                                'label': label,
                                'image_path': os.path.join(root, file)
                            }
                        )

    return dataset

def create_front_extract():
    pretrained_model_chosen = tf.keras.applications.resnet50.ResNet50
    pretrained_model = pretrained_model_chosen(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg')
    pretrained_model.trainable = False
    return pretrained_model

def create_side_extract():
    pretrained_model_chosen = tf.keras.applications.efficientnet.EfficientNetB0
    pretrained_model = pretrained_model_chosen(
        input_shape=(224, 224, 3),
        include_top=False,
        weights='imagenet',
        pooling='avg')
    pretrained_model.trainable = False
    return pretrained_model

def multi_input_generator(front_gen, side_gen):
    while True:
        front_batch, y1 = next(front_gen)
        side_batch, y2 = next(side_gen)
        assert (y1 == y2).all(), "Label mismatch!"  # 確保標籤一致
        yield ([front_batch, side_batch], y1)


# def train_cross_validation(image_dir, n_splits=5, class_count=2, maru_part=None,  chosen_model='resnet50'):
def train_cross_validation(image_dir, n_splits=5, class_count=2):


    ## load data and  labels
    # =========================
    labels = []
    filepaths = []
    data = load_path(image_dir, class_count)
    for row in data:
        labels.append(row['label'])
        filepaths.append(row['image_path'])

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    images = pd.concat([filepaths, labels], axis=1)
    # =========================

    ## split image
    # =========================
    train_df_front, test_df_front = train_test_split(images, train_size=0.8, shuffle=True, random_state=1, stratify=images['Label'])
    print("Training set label distribution:\n", train_df_front['Label'].value_counts(normalize=False))
    print("Test set label distribution:\n", test_df_front['Label'].value_counts(normalize=False))
    # =========================

    preprocessing_function_chosen_front = tf.keras.applications.resnet50.preprocess_input
    preprocessing_function_chosen_side = tf.keras.applications.efficientnet.preprocess_input


    ## train model, k fold cross validation
    # ==================================================
    fold_no = 1
    test_acc = []
    test_f1 = []

    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
    for train_index, val_index in kfold.split(train_df_front, train_df_front['Label']):
        k_fold_train_front = train_df_front.iloc[train_index]
        k_fold_val_front = train_df_front.iloc[val_index]

        # front images
        # =========================
        train_generator_front = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,
                                                                                preprocessing_function=preprocessing_function_chosen_front)
        test_generator_front = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen_front)

        train_images_front = train_generator_front.flow_from_dataframe(
            dataframe=k_fold_train_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        val_images_front = train_generator_front.flow_from_dataframe(
            dataframe=k_fold_val_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        test_images_front = test_generator_front.flow_from_dataframe(
            dataframe=test_df_front,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=32,
            shuffle=False
        )
        # =========================   

        # side images
        # =========================
        train_df_side = train_df_front.copy()
        test_df_side = test_df_front.copy()
        train_df_side.loc[:, "Filepath"] = train_df_front["Filepath"].str.replace("front", "side")
        test_df_side.loc[:, "Filepath"] = test_df_side["Filepath"].str.replace("front", "side")

        k_fold_train_side = train_df_side.iloc[train_index]
        k_fold_val_side = train_df_side.iloc[val_index]

        train_generator_side = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,
                                                                                preprocessing_function=preprocessing_function_chosen_side)
        test_generator_side = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen_side)

        train_images_side = train_generator_side.flow_from_dataframe(
            dataframe=k_fold_train_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        val_images_side = train_generator_side.flow_from_dataframe(
            dataframe=k_fold_val_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )

        test_images_side = test_generator_side.flow_from_dataframe(
            dataframe=test_df_side,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=32,
            shuffle=False
        )
        # ========================= 
        
        # load model
        # =========================
        # input 
        input_front = Input(shape=(224, 224, 3), name="AP(Mortise)")
        input_side = Input(shape=(224, 224, 3), name="Lateral")

        # model
        model_front = create_front_extract()
        model_side = create_side_extract()

        features_front = model_front(input_front)
        features_side = model_side(input_side)

        features_front_x = tf.keras.layers.Dense(128, activation='relu', name='AP_dense_128')(features_front)
        features_front_x = tf.keras.layers.Dense(50, activation='relu', name='AP_dense_50')(features_front_x)

        features_side_x = tf.keras.layers.Dense(128, activation='relu', name='Lateral_dense_128')(features_side)
        features_side_x = tf.keras.layers.Dense(50, activation='relu', name='Lateral_dense_50')(features_side_x)

        fused_features = Concatenate(name="feature_fusion")([features_front_x, features_side_x])
        # fused_features = tf.keras.layers.Dense(50, activation='relu', name='fusion_dense_50')(fused_features)
        fused_features = Dropout(0.1)(fused_features)

        final_output = Dense(class_count, activation='sigmoid', name='output_layer')(fused_features)
        multi_view_model = None
        multi_view_model = Model(
            inputs=[input_front, input_side],
            outputs=final_output
        )
        multi_view_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

        multi_view_model.summary()
        # print(model.summary())
        # =========================

        train_generator = multi_input_generator(train_images_front, train_images_side)
        val_generator = multi_input_generator(val_images_front, val_images_side)
        
        ## compile and evaluate
        # =========================

        print("-------Training_" + concat_type + "-------")
        multi_view_model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
        
        batch_size = 64
        ## early stop 
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
        multi_view_model.fit(train_generator, validation_data=val_generator, callbacks=[early_stopping], epochs=30,
                                    steps_per_epoch= math.ceil(train_images_front.samples / batch_size), 
                                    validation_steps= math.ceil(val_images_front.samples / batch_size))
        ## no early stop
        # multi_view_model.fit(train_generator, validation_data=val_generator, epochs=30,
        #                     steps_per_epoch= math.ceil(train_images_front.samples / batch_size), 
        #                     validation_steps= math.ceil(val_images_front.samples / batch_size))

        # =========================

        test_generator = multi_input_generator(test_images_front, test_images_side)
        batch_size=32
        pred = multi_view_model.predict(test_generator,  steps=math.ceil(test_images_front.samples / batch_size))
        predicted_labels = np.argmax(pred, axis=1)

        # =========================
            
        ## print results
        # =========================
        acc = accuracy_score(test_images_front.labels, predicted_labels)

        test_acc.append(np.round(acc, 2))
        f1 = f1_score(test_images_front.labels, predicted_labels, average='macro')
        test_f1.append(np.round(f1, 2))
        fold_no += 1
        # =========================
    # ==================================================
        
    ## print  mean results
    # =========================
    acc_mean  = np.round(np.mean(test_acc), 2)
    acc_std = np.round(np.std(test_acc), 2)
    f1_mean  = np.round(np.mean(test_f1), 2)
    f1_std = np.round(np.std(test_f1), 2)
    # print(f"acc mean = {acc_mean}, std = {acc_std}")
    # print(test_acc)
    # print(f"f1  mean = {f1_mean}, std = {f1_std}")
    # print(test_f1)
    # =========================

    return {'acc_mean':acc_mean, 'acc_std':acc_std, 'test_acc':test_acc, 'f1_mean':f1_mean, 'f1_std':f1_std, 'test_f1':test_f1}


path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\front"

concat_type = "concat1"


# =========================




results = []
results = train_cross_validation(image_dir=path, class_count=3)


print(f"acc mean = {results['acc_mean']}, std = {results['acc_std']}, test_acc = {results['test_acc']}")
print(f"f1  mean = {results['f1_mean']}, std = {results['f1_std']}, test_f1 = {results['test_f1']}")
# Out:
# Training set label distribution:
#  0    128
# 2     95
# 1     93
# Name: Label, dtype: int64
# Test set label distribution:
#  0    32
# 1    24
# 2    24
# Name: Label, dtype: int64
# Found 252 validated image filenames belonging to 3 classes.
# Found 64 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 252 validated image filenames belonging to 3 classes.
# Found 64 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_10[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 6s 876ms/step - loss: 1.1413 - accuracy: 0.3968 - val_loss: 1.0152 - val_accuracy: 0.5156
# Epoch 2/30
# 4/4 [==============================] - 2s 640ms/step - loss: 0.9942 - accuracy: 0.5357 - val_loss: 0.9161 - val_accuracy: 0.6562
# Epoch 3/30
# 4/4 [==============================] - 2s 665ms/step - loss: 0.8845 - accuracy: 0.6230 - val_loss: 0.8326 - val_accuracy: 0.6250
# Epoch 4/30
# 4/4 [==============================] - 2s 630ms/step - loss: 0.7860 - accuracy: 0.6825 - val_loss: 0.7720 - val_accuracy: 0.7188
# Epoch 5/30
# 4/4 [==============================] - 2s 631ms/step - loss: 0.7195 - accuracy: 0.7341 - val_loss: 0.7221 - val_accuracy: 0.7500
# Epoch 6/30
# 4/4 [==============================] - 2s 630ms/step - loss: 0.6891 - accuracy: 0.7500 - val_loss: 0.6850 - val_accuracy: 0.7812
# Epoch 7/30
# 4/4 [==============================] - 2s 656ms/step - loss: 0.6435 - accuracy: 0.7222 - val_loss: 0.6556 - val_accuracy: 0.7500
# Epoch 8/30
# 4/4 [==============================] - 2s 625ms/step - loss: 0.5955 - accuracy: 0.7817 - val_loss: 0.6311 - val_accuracy: 0.7188
# Epoch 9/30
# 4/4 [==============================] - 2s 611ms/step - loss: 0.5730 - accuracy: 0.7817 - val_loss: 0.6114 - val_accuracy: 0.7500
# Epoch 10/30
# 4/4 [==============================] - 2s 619ms/step - loss: 0.5329 - accuracy: 0.7937 - val_loss: 0.5958 - val_accuracy: 0.7500
# Epoch 11/30
# 4/4 [==============================] - 2s 619ms/step - loss: 0.5291 - accuracy: 0.7976 - val_loss: 0.5819 - val_accuracy: 0.7344
# Epoch 12/30
# 4/4 [==============================] - 2s 618ms/step - loss: 0.5026 - accuracy: 0.8056 - val_loss: 0.5693 - val_accuracy: 0.7344
# Epoch 13/30
# 4/4 [==============================] - 2s 617ms/step - loss: 0.4785 - accuracy: 0.8333 - val_loss: 0.5569 - val_accuracy: 0.7344
# Epoch 14/30
# 4/4 [==============================] - 2s 615ms/step - loss: 0.4463 - accuracy: 0.8413 - val_loss: 0.5459 - val_accuracy: 0.7656
# Epoch 15/30
# 4/4 [==============================] - 2s 614ms/step - loss: 0.4534 - accuracy: 0.8373 - val_loss: 0.5356 - val_accuracy: 0.7812
# Epoch 16/30
# 4/4 [==============================] - 2s 605ms/step - loss: 0.4276 - accuracy: 0.8770 - val_loss: 0.5283 - val_accuracy: 0.7812
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_11[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 6s 925ms/step - loss: 1.1923 - accuracy: 0.4111 - val_loss: 1.0122 - val_accuracy: 0.4127
# Epoch 2/30
# 4/4 [==============================] - 2s 632ms/step - loss: 0.9813 - accuracy: 0.4980 - val_loss: 0.9419 - val_accuracy: 0.5714
validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_12"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_12[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 8s 1s/step - loss: 1.0792 - accuracy: 0.4269 - val_loss: 1.0057 - val_accuracy: 0.5238
# Epoch 2/30
# 4/4 [==============================] - 3s 828ms/step - loss: 0.9596 - accuracy: 0.6166 - val_loss: 0.9404 - val_accuracy: 0.6508
# Epoch 3/30
# 4/4 [==============================] - 3s 812ms/step - loss: 0.8904 - accuracy: 0.6798 - val_loss: 0.8610 - val_accuracy: 0.6667
# Epoch 4/30
# 4/4 [==============================] - 3s 796ms/step - loss: 0.8237 - accuracy: 0.7115 - val_loss: 0.7975 - val_accuracy: 0.6190
# Epoch 5/30
# 4/4 [==============================] - 3s 804ms/step - loss: 0.7516 - accuracy: 0.7273 - val_loss: 0.7513 - val_accuracy: 0.6349
# Epoch 6/30
# 4/4 [==============================] - 3s 802ms/step - loss: 0.7133 - accuracy: 0.7628 - val_loss: 0.7077 - val_accuracy: 0.6984
# Epoch 7/30
# 4/4 [==============================] - 2s 731ms/step - loss: 0.6743 - accuracy: 0.7747 - val_loss: 0.6725 - val_accuracy: 0.6984
# Epoch 8/30
# 4/4 [==============================] - 2s 765ms/step - loss: 0.6416 - accuracy: 0.7549 - val_loss: 0.6461 - val_accuracy: 0.6984
# Epoch 9/30
# 4/4 [==============================] - 3s 827ms/step - loss: 0.6036 - accuracy: 0.7945 - val_loss: 0.6223 - val_accuracy: 0.7143
# Epoch 10/30
# 4/4 [==============================] - 2s 751ms/step - loss: 0.5966 - accuracy: 0.8103 - val_loss: 0.6009 - val_accuracy: 0.7143
# Epoch 11/30
# 4/4 [==============================] - 2s 752ms/step - loss: 0.5743 - accuracy: 0.8063 - val_loss: 0.5812 - val_accuracy: 0.7143
# Epoch 12/30
# 4/4 [==============================] - 3s 783ms/step - loss: 0.5299 - accuracy: 0.8142 - val_loss: 0.5639 - val_accuracy: 0.7143
# Epoch 13/30
# 4/4 [==============================] - 3s 786ms/step - loss: 0.5229 - accuracy: 0.8379 - val_loss: 0.5463 - val_accuracy: 0.7302
# Epoch 14/30
# 4/4 [==============================] - 3s 914ms/step - loss: 0.5039 - accuracy: 0.7984 - val_loss: 0.5329 - val_accuracy: 0.7302
# Epoch 15/30
# 4/4 [==============================] - 2s 744ms/step - loss: 0.4702 - accuracy: 0.8419 - val_loss: 0.5214 - val_accuracy: 0.7460
# Epoch 16/30
# 4/4 [==============================] - 2s 766ms/step - loss: 0.4642 - accuracy: 0.8498 - val_loss: 0.5091 - val_accuracy: 0.7460
# Epoch 17/30
# 4/4 [==============================] - 3s 797ms/step - loss: 0.4427 - accuracy: 0.8498 - val_loss: 0.4984 - val_accuracy: 0.7619
# Epoch 18/30
# 4/4 [==============================] - 3s 804ms/step - loss: 0.4550 - accuracy: 0.8498 - val_loss: 0.4884 - val_accuracy: 0.7778
# Epoch 19/30
# 4/4 [==============================] - 3s 793ms/step - loss: 0.4060 - accuracy: 0.8814 - val_loss: 0.4800 - val_accuracy: 0.7778
# Epoch 20/30
# 4/4 [==============================] - 3s 806ms/step - loss: 0.4216 - accuracy: 0.8577 - val_loss: 0.4731 - val_accuracy: 0.7778
# Epoch 21/30
# 4/4 [==============================] - 3s 785ms/step - loss: 0.4007 - accuracy: 0.8814 - val_loss: 0.4681 - val_accuracy: 0.7937
# Epoch 22/30
# 4/4 [==============================] - 2s 727ms/step - loss: 0.3835 - accuracy: 0.8933 - val_loss: 0.4615 - val_accuracy: 0.7937
# Epoch 23/30
# 4/4 [==============================] - 3s 801ms/step - loss: 0.3755 - accuracy: 0.8972 - val_loss: 0.4545 - val_accuracy: 0.8095
# Epoch 24/30
# 4/4 [==============================] - 3s 814ms/step - loss: 0.3605 - accuracy: 0.8893 - val_loss: 0.4497 - val_accuracy: 0.8095
# Epoch 25/30
# 4/4 [==============================] - 3s 795ms/step - loss: 0.3540 - accuracy: 0.9170 - val_loss: 0.4447 - val_accuracy: 0.8095
# Epoch 26/30
# 4/4 [==============================] - 2s 779ms/step - loss: 0.3553 - accuracy: 0.8854 - val_loss: 0.4395 - val_accuracy: 0.8095
# Epoch 27/30
# 4/4 [==============================] - 3s 785ms/step - loss: 0.3561 - accuracy: 0.9091 - val_loss: 0.4346 - val_accuracy: 0.8095
# Epoch 28/30
# 4/4 [==============================] - 3s 815ms/step - loss: 0.3354 - accuracy: 0.9249 - val_loss: 0.4319 - val_accuracy: 0.8254
# Epoch 29/30
# 4/4 [==============================] - 2s 774ms/step - loss: 0.3243 - accuracy: 0.9209 - val_loss: 0.4276 - val_accuracy: 0.8095
# Epoch 30/30
# 4/4 [==============================] - 2s 719ms/step - loss: 0.3157 - accuracy: 0.9130 - val_loss: 0.4240 - val_accuracy: 0.7937
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_13[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 9s 1s/step - loss: 1.1302 - accuracy: 0.4387 - val_loss: 0.9821 - val_accuracy: 0.5714
# Epoch 2/30
# 4/4 [==============================] - 3s 901ms/step - loss: 0.9659 - accuracy: 0.5573 - val_loss: 0.9189 - val_accuracy: 0.5873
# Epoch 3/30
# 4/4 [==============================] - 3s 800ms/step - loss: 0.8781 - accuracy: 0.6522 - val_loss: 0.8540 - val_accuracy: 0.6825
# Epoch 4/30
# 4/4 [==============================] - 2s 745ms/step - loss: 0.8102 - accuracy: 0.6917 - val_loss: 0.8053 - val_accuracy: 0.6825
# Epoch 5/30
# 4/4 [==============================] - 2s 735ms/step - loss: 0.7499 - accuracy: 0.7431 - val_loss: 0.7668 - val_accuracy: 0.6825
# Epoch 6/30
# 4/4 [==============================] - 2s 657ms/step - loss: 0.7117 - accuracy: 0.7075 - val_loss: 0.7354 - val_accuracy: 0.6984
# Epoch 7/30
# 4/4 [==============================] - 2s 627ms/step - loss: 0.6617 - accuracy: 0.7787 - val_loss: 0.7099 - val_accuracy: 0.6667
# Epoch 8/30
# 4/4 [==============================] - 2s 633ms/step - loss: 0.6194 - accuracy: 0.8261 - val_loss: 0.6853 - val_accuracy: 0.6508
# Epoch 9/30
# 4/4 [==============================] - 2s 655ms/step - loss: 0.5863 - accuracy: 0.8103 - val_loss: 0.6633 - val_accuracy: 0.6825
# Epoch 10/30
# 4/4 [==============================] - 2s 620ms/step - loss: 0.5746 - accuracy: 0.7668 - val_loss: 0.6440 - val_accuracy: 0.6984
# Epoch 11/30
# 4/4 [==============================] - 2s 620ms/step - loss: 0.5511 - accuracy: 0.7787 - val_loss: 0.6320 - val_accuracy: 0.6984
# Epoch 12/30
# 4/4 [==============================] - 2s 620ms/step - loss: 0.4929 - accuracy: 0.8379 - val_loss: 0.6196 - val_accuracy: 0.6825
# Epoch 13/30
# 4/4 [==============================] - 2s 614ms/step - loss: 0.4723 - accuracy: 0.8498 - val_loss: 0.6090 - val_accuracy: 0.6667
# Epoch 14/30
# 4/4 [==============================] - 2s 620ms/step - loss: 0.4616 - accuracy: 0.8379 - val_loss: 0.5938 - val_accuracy: 0.6984
# Epoch 15/30
# 4/4 [==============================] - 2s 651ms/step - loss: 0.4709 - accuracy: 0.8617 - val_loss: 0.5824 - val_accuracy: 0.6825
# Epoch 16/30
# 4/4 [==============================] - 2s 610ms/step - loss: 0.4396 - accuracy: 0.8538 - val_loss: 0.5762 - val_accuracy: 0.6825
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Found 253 validated image filenames belonging to 3 classes.
# Found 63 validated image filenames belonging to 3 classes.
# Found 80 validated image filenames belonging to 3 classes.
# Model: "model_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# AP(Mortise) (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Lateral (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# resnet50 (Functional)           (None, 2048)         23587712    AP(Mortise)[0][0]
# __________________________________________________________________________________________________
# efficientnetb0 (Functional)     (None, 1280)         4049571     Lateral[0][0]
# __________________________________________________________________________________________________
# AP_dense_128 (Dense)            (None, 128)          262272      resnet50[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_128 (Dense)       (None, 128)          163968      efficientnetb0[0][0]
# __________________________________________________________________________________________________
# AP_dense_50 (Dense)             (None, 50)           6450        AP_dense_128[0][0]
# __________________________________________________________________________________________________
# Lateral_dense_50 (Dense)        (None, 50)           6450        Lateral_dense_128[0][0]
# __________________________________________________________________________________________________
# feature_fusion (Concatenate)    (None, 100)          0           AP_dense_50[0][0]
#                                                                  Lateral_dense_50[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 100)          0           feature_fusion[0][0]
# __________________________________________________________________________________________________
# output_layer (Dense)            (None, 3)            303         dropout_14[0][0]
# ==================================================================================================
# Total params: 28,076,726
# Trainable params: 439,443
# Non-trainable params: 27,637,283
# __________________________________________________________________________________________________
# -------Training_concat1-------
# Epoch 1/30
# 4/4 [==============================] - 6s 941ms/step - loss: 1.0221 - accuracy: 0.4862 - val_loss: 0.9440 - val_accuracy: 0.6190
# Epoch 2/30
# 4/4 [==============================] - 2s 637ms/step - loss: 0.8936 - accuracy: 0.6285 - val_loss: 0.8689 - val_accuracy: 0.6349
# Epoch 3/30
# 4/4 [==============================] - 2s 649ms/step - loss: 0.8056 - accuracy: 0.6719 - val_loss: 0.8066 - val_accuracy: 0.6984
# Epoch 4/30
# 4/4 [==============================] - 2s 675ms/step - loss: 0.7225 - accuracy: 0.7154 - val_loss: 0.7575 - val_accuracy: 0.7143
# Epoch 5/30
# 4/4 [==============================] - 2s 624ms/step - loss: 0.6755 - accuracy: 0.7391 - val_loss: 0.7194 - val_accuracy: 0.7302
# Epoch 6/30
# 4/4 [==============================] - 2s 620ms/step - loss: 0.6527 - accuracy: 0.7233 - val_loss: 0.6867 - val_accuracy: 0.7460
# Epoch 7/30
# 4/4 [==============================] - 2s 626ms/step - loss: 0.5826 - accuracy: 0.7787 - val_loss: 0.6646 - val_accuracy: 0.7143
# Epoch 8/30
# 4/4 [==============================] - 2s 637ms/step - loss: 0.5677 - accuracy: 0.7589 - val_loss: 0.6447 - val_accuracy: 0.7302
# Epoch 9/30
# 4/4 [==============================] - 2s 638ms/step - loss: 0.5242 - accuracy: 0.8300 - val_loss: 0.6288 - val_accuracy: 0.7619
# Epoch 10/30
# 4/4 [==============================] - 2s 629ms/step - loss: 0.5071 - accuracy: 0.7945 - val_loss: 0.6154 - val_accuracy: 0.7619
# Epoch 11/30
# 4/4 [==============================] - 2s 621ms/step - loss: 0.4845 - accuracy: 0.8340 - val_loss: 0.6058 - val_accuracy: 0.7460
# Epoch 12/30
# 4/4 [==============================] - 2s 632ms/step - loss: 0.4615 - accuracy: 0.8142 - val_loss: 0.5883 - val_accuracy: 0.7619
# Epoch 13/30
# 4/4 [==============================] - 2s 671ms/step - loss: 0.4407 - accuracy: 0.8617 - val_loss: 0.5735 - val_accuracy: 0.7778
# Epoch 14/30
# 4/4 [==============================] - 2s 625ms/step - loss: 0.4231 - accuracy: 0.8656 - val_loss: 0.5655 - val_accuracy: 0.7778
# Epoch 15/30
# 4/4 [==============================] - 2s 622ms/step - loss: 0.4215 - accuracy: 0.8735 - val_loss: 0.5578 - val_accuracy: 0.7778
# Epoch 16/30
# 4/4 [==============================] - 2s 621ms/step - loss: 0.3784 - accuracy: 0.8814 - val_loss: 0.5552 - val_accuracy: 0.7778
# Epoch 17/30
# 4/4 [==============================] - 2s 616ms/step - loss: 0.3741 - accuracy: 0.8854 - val_loss: 0.5478 - val_accuracy: 0.7778
# Epoch 18/30
# 4/4 [==============================] - 2s 645ms/step - loss: 0.3747 - accuracy: 0.8696 - val_loss: 0.5424 - val_accuracy: 0.7778
# Epoch 19/30
# 4/4 [==============================] - 2s 657ms/step - loss: 0.3546 - accuracy: 0.8972 - val_loss: 0.5378 - val_accuracy: 0.7778
# Epoch 20/30
# 4/4 [==============================] - 2s 665ms/step - loss: 0.3428 - accuracy: 0.8814 - val_loss: 0.5350 - val_accuracy: 0.7937
# Epoch 21/30
# 4/4 [==============================] - 3s 880ms/step - loss: 0.3218 - accuracy: 0.8972 - val_loss: 0.5347 - val_accuracy: 0.7778
# Epoch 22/30
# 4/4 [==============================] - 3s 863ms/step - loss: 0.3185 - accuracy: 0.9012 - val_loss: 0.5358 - val_accuracy: 0.7460
# Epoch 23/30
# 4/4 [==============================] - 2s 759ms/step - loss: 0.3013 - accuracy: 0.9170 - val_loss: 0.5300 - val_accuracy: 0.7778
# Epoch 24/30
# 4/4 [==============================] - 3s 814ms/step - loss: 0.2909 - accuracy: 0.9091 - val_loss: 0.5249 - val_accuracy: 0.7778
# Epoch 25/30
# 4/4 [==============================] - 2s 758ms/step - loss: 0.2768 - accuracy: 0.9368 - val_loss: 0.5233 - val_accuracy: 0.7778
# Epoch 26/30
# 4/4 [==============================] - 3s 786ms/step - loss: 0.2799 - accuracy: 0.9368 - val_loss: 0.5206 - val_accuracy: 0.7778
# Epoch 27/30
# 4/4 [==============================] - 3s 827ms/step - loss: 0.2604 - accuracy: 0.9486 - val_loss: 0.5215 - val_accuracy: 0.7778
# Epoch 28/30
# 4/4 [==============================] - 3s 794ms/step - loss: 0.2362 - accuracy: 0.9526 - val_loss: 0.5176 - val_accuracy: 0.7937
# Epoch 29/30
# 4/4 [==============================] - 3s 807ms/step - loss: 0.2431 - accuracy: 0.9605 - val_loss: 0.5205 - val_accuracy: 0.7778
# Epoch 30/30
# 4/4 [==============================] - 3s 780ms/step - loss: 0.2433 - accuracy: 0.9526 - val_loss: 0.5120 - val_accuracy: 0.7937
# acc mean = 0.75, std = 0.05, test_acc = [0.68, 0.79, 0.8, 0.7, 0.8]
# f1  mean = 0.73, std = 0.06, test_f1 = [0.64, 0.77, 0.78, 0.67, 0.78]
