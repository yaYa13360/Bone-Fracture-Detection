# %%
path = "E:\\data_bone\\11-a+b_swift_cut_正確_V2_踢盲檢\\side"

# %%
# import
import numpy as np
import pandas as pd
import os.path
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt
import os

## label
# =========================
def class_2_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    else:
        label = "1"
    return label

# def class_4_type(root):
#     label = ""
#     if "0" in root:
#         label = "0"
#     elif "1" in root:
#         label = "1"
#     elif "2" in root:
#         label = "2"
#     else:
#         label = "3"
#     return label

# def class_2_type(root):
#     label = ""
#     if "雙踝" in root:
#         label = "0"
#     elif "三踝" in root:
#         label = "1"
#     return label

def class_3_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    elif "雙踝" in root:
        label = "1"
    elif "三踝" in root:
        label = "2"
    return label
# =========================


def load_path(path, class_count):
    dataset = []
    class_type = ''
    if class_count == 2:
        class_type = class_2_type
    elif class_count == 3:
        class_type = class_3_type  
    # elif class_count == 4:
    #     class_type = class_4_type     

    for root, dirs, files in os.walk(path):
        for file in files:
            label = class_type(root)
            # if label != "":
            dataset.append(
                            {   
                                'uuid': root.split("\\")[-1],
                                'label': label,
                                'image_path': os.path.join(root, file)
                            }
                        )

    return dataset

def train_cross_validation(image_dir, n_splits=5, class_count=2, maru_part=None,  chosen_model='resnet50'):


    ## load data and  labels
    # =========================
    labels = []
    filepaths = []
    data = load_path(image_dir, class_count)
    for row in data:
        labels.append(row['label'])
        filepaths.append(row['image_path'])

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    images = pd.concat([filepaths, labels], axis=1)
    # =========================
    

    ## front(AP+Mortise) or side(Lateral) 標籤
    # =========================
    part = ""
    if image_dir.split("//")[-1] == "front":
        part = "AP+Mortise"
    else:
        part = "Lateral"
    # =========================

    ## load chosen model
    # =========================
    if chosen_model == 'resnet50':
        preprocessing_function_chosen = tf.keras.applications.resnet50.preprocess_input
        pretrained_model_chosen = tf.keras.applications.resnet50.ResNet50
    # elif chosen_model == 'resnet152':
    #     preprocessing_function_chosen = tf.keras.applications.resnet152.preprocess_input
    #     pretrained_model_chosen = tf.keras.applications.resnet152.ResNet152
    elif chosen_model == 'vgg16':
        preprocessing_function_chosen = tf.keras.applications.vgg16.preprocess_input
        pretrained_model_chosen = tf.keras.applications.vgg16.VGG16
    elif chosen_model == 'vgg19':
        preprocessing_function_chosen = tf.keras.applications.vgg19.preprocess_input
        pretrained_model_chosen = tf.keras.applications.vgg19.VGG19
    elif chosen_model == 'mobilenet':
        preprocessing_function_chosen = tf.keras.applications.mobilenet.preprocess_input
        pretrained_model_chosen = tf.keras.applications.mobilenet.MobileNet
    elif chosen_model == 'mobilenet_v2':
        preprocessing_function_chosen = tf.keras.applications.mobilenet_v2.preprocess_input
        pretrained_model_chosen = tf.keras.applications.mobilenet_v2.MobileNetV2
    elif chosen_model == 'efficientnet':
        preprocessing_function_chosen = tf.keras.applications.efficientnet.preprocess_input
        pretrained_model_chosen = tf.keras.applications.efficientnet.EfficientNetB0
    elif chosen_model == 'inception_v3':
        preprocessing_function_chosen = tf.keras.applications.inception_v3.preprocess_input
        pretrained_model_chosen = tf.keras.applications.inception_v3.InceptionV3
    else:
        raise ValueError("Model name not recognized. Please choose a valid model.")




    # =========================

    ## to do: loss function
    # =========================
    # =========================


    print("-------Training " + part + "-------")
    train_df, test_df = train_test_split(images, train_size=0.8, shuffle=True, random_state=1, stratify=images['Label'])

    ## test  image
    # =========================
    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen)
    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )
    # =========================

    ## train model, k fold cross validation
    # ==================================================
    fold_no = 1
    test_acc = []
    test_f1 = []
    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
    for train_index, val_index in kfold.split(train_df, train_df['Label']):
        k_fold_train = train_df.iloc[train_index]
        k_fold_val = train_df.iloc[val_index]
        # print("K-fold training set label distribution:\n", k_fold_train['Label'].value_counts(normalize=True))
        # print("K-fold validation set label distribution:\n", k_fold_val['Label'].value_counts(normalize=True))
        
        ## train, validation image
        # =========================
        # 關閉翻轉
        train_generator = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,preprocessing_function=preprocessing_function_chosen)
        val_generator = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen)
        train_images = train_generator.flow_from_dataframe(
            dataframe=k_fold_train,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=True,
            seed=42
        )
        val_images = val_generator.flow_from_dataframe(
            dataframe=k_fold_val,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )
        # =========================
        
        ## load model
        # =========================
        if maru_part is not None:
            pretrained_model = tf.keras.models.load_model(maru_part)
        else:
            pretrained_model = pretrained_model_chosen(
                input_shape=(224, 224, 3),
                include_top=False,
                weights='imagenet',
                pooling='avg')

        pretrained_model.trainable = False

        inputs = pretrained_model.input
        x = tf.keras.layers.Dense(128, activation='relu', name='dense_128')(pretrained_model.output)
        x = tf.keras.layers.Dense(50, activation='relu', name='dense_50')(x)

        outputs = tf.keras.layers.Dense(class_count, activation='softmax', name='output_layer')(x)
        model = tf.keras.Model(inputs, outputs)
        # print(model.summary())
        # =========================

        ## compile and evaluate
        # =========================
        model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

       ## early stop 
        # early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
        # model.fit(train_images, validation_data=val_images, callbacks=[early_stopping], epochs=30)
        
        ## no early stop
        model.fit(train_images, validation_data=val_images, epochs=30)

        results = model.evaluate(test_images,  verbose=0)
        # =========================

        ## print each results
        # =========================
        test_acc.append(np.round(results[1], 2))
        pred = model.predict(test_images)
        predicted_labels = np.argmax(pred, axis=1)
        f1 = f1_score(test_images.labels, predicted_labels, average='macro')
        test_f1.append(np.round(f1, 2))
        fold_no += 1
        # =========================
    # ==================================================
        
    ## print  mean results
    # =========================
    acc_mean  = np.round(np.mean(test_acc), 2)
    acc_std = np.round(np.std(test_acc), 2)
    f1_mean  = np.round(np.mean(test_f1), 2)
    f1_std = np.round(np.std(test_f1), 2)
    # print(f"acc mean = {acc_mean}, std = {acc_std}")
    # print(test_acc)
    # print(f"f1  mean = {f1_mean}, std = {f1_std}")
    # print(test_f1)
    # =========================

    return {'acc_mean':acc_mean, 'acc_std':acc_std, 'test_acc':test_acc, 'f1_mean':f1_mean, 'f1_std':f1_std, 'test_f1':test_f1}


#####################################
# train_cross_validation: 訓練
#############
## image_dir: 影像來源
## class_count: 分幾個class
## n_splits: 幾折
## maru_part: 用maru哪個部位的模型pretrain
#############

# load_path: load image
#############
## path: 影像來源
## class_count: 分幾個class
## n_splits: 幾折
#############

# class_2_type, class_3_type: 種類標籤, 回傳label種類標籤, 回傳label

#####################################



## 訓練front or side
# =========================
# path = "E://data_bone//4-a+b_swift_cut_正確//side"
# path = "E://data_bone//4-a+b_swift_cut_正確//front"

# path = "E://data_bone//3-a+b_all_正確//side"
# path = "E://data_bone//3-a+b_all_正確//front"

# path = "E://data_bone//5-a+b_swift_cut_標準//side"
# path = "E://data_bone//5-a+b_swift_cut_標準//front"

# path = "E://data_bone//6-a+b_swift_cut_正確_5cluster//side"
# path = "E://data_bone//6-a+b_swift_cut_正確_5cluster//front"


# path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\side"
# path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\front"
# =========================

chosen_models = [
    'resnet50',
    # 'resnet152',
    'vgg16',
    'vgg19',
    'mobilenet',
    'mobilenet_v2',
    'efficientnet',
    'inception_v3'
]

results1 = []
print(len(chosen_models))
for i in range(len(chosen_models)):
    tmp = train_cross_validation(image_dir=path, class_count=3, chosen_model=chosen_models[i])
    results1.append(tmp)

for i in range(len(chosen_models)):
    print(f'----------------------Model {chosen_models[i]}----------------------')
    print(f"acc mean = {results1[i]['acc_mean']}, std = {results1[i]['acc_std']}, test_acc = {results1[i]['test_acc']}")
    print(f"f1  mean = {results1[i]['f1_mean']}, std = {results1[i]['f1_std']}, test_f1 = {results1[i]['test_f1']}")
# Out:
# 7
# -------Training Lateral-------
# Found 60 validated image filenames belonging to 3 classes.
# Found 189 validated image filenames belonging to 3 classes.
# Found 48 validated image filenames belonging to 3 classes.
# Epoch 1/30
# 3/3 [==============================] - 3s 533ms/step - loss: 1.3969 - accuracy: 0.3016 - val_loss: 1.1585 - val_accuracy: 0.4167
# Epoch 2/30
# 3/3 [==============================] - 1s 331ms/step - loss: 1.1525 - accuracy: 0.4127 - val_loss: 1.0637 - val_accuracy: 0.4583
# Epoch 3/30
# 3/3 [==============================] - 1s 339ms/step - loss: 1.0709 - accuracy: 0.4444 - val_loss: 1.0032 - val_accuracy: 0.4583
# Epoch 4/30
# 3/3 [==============================] - 1s 338ms/step - loss: 1.0039 - accuracy: 0.4868 - val_loss: 0.9183 - val_accuracy: 0.6458
# Epoch 5/30
# 3/3 [==============================] - 1s 360ms/step - loss: 0.9213 - accuracy: 0.6190 - val_loss: 0.8597 - val_accuracy: 0.6042
# Epoch 6/30
# 3/3 [==============================] - 1s 343ms/step - loss: 0.8642 - accuracy: 0.6614 - val_loss: 0.8188 - val_accuracy: 0.6667
# Epoch 7/30
# 3/3 [==============================] - 1s 340ms/step - loss: 0.8183 - accuracy: 0.6720 - val_loss: 0.7735 - val_accuracy: 0.6667
# Epoch 8/30
# 3/3 [==============================] - 1s 312ms/step - loss: 0.7774 - accuracy: 0.6825 - val_loss: 0.7265 - val_accuracy: 0.6875
# Epoch 9/30
# 3/3 [==============================] - 1s 349ms/step - loss: 0.7340 - accuracy: 0.7196 - val_loss: 0.6823 - val_accuracy: 0.7917
# Epoch 10/30
# 3/3 [==============================] - 1s 371ms/step - loss: 0.6988 - accuracy: 0.7513 - val_loss: 0.6447 - val_accuracy: 0.7917
# Epoch 11/30
# 3/3 [==============================] - 1s 351ms/step - loss: 0.6693 - accuracy: 0.7989 - val_loss: 0.6192 - val_accuracy: 0.7500
# Epoch 12/30
# 3/3 [==============================] - 1s 337ms/step - loss: 0.6399 - accuracy: 0.7989 - val_loss: 0.5981 - val_accuracy: 0.7917
# Epoch 13/30
# 3/3 [==============================] - 1s 346ms/step - loss: 0.6121 - accuracy: 0.7937 - val_loss: 0.5855 - val_accuracy: 0.7917
# Epoch 14/30
# 3/3 [==============================] - 1s 337ms/step - loss: 0.5900 - accuracy: 0.7884 - val_loss: 0.5723 - val_accuracy: 0.7917
# Epoch 15/30
# 3/3 [==============================] - 1s 348ms/step - loss: 0.5694 - accuracy: 0.7937 - val_loss: 0.5579 - val_accuracy: 0.7917
# Epoch 16/30
# 3/3 [==============================] - 1s 336ms/step - loss: 0.5485 - accuracy: 0.8095 - val_loss: 0.5451 - val_accuracy: 0.7708
# Epoch 17/30
# 3/3 [==============================] - 1s 334ms/step - loss: 0.5300 - accuracy: 0.8307 - val_loss: 0.5316 - val_accuracy: 0.7708
# Epoch 18/30
# 3/3 [==============================] - 1s 337ms/step - loss: 0.5135 - accuracy: 0.8360 - val_loss: 0.5207 - val_accuracy: 0.7708
# Epoch 19/30
# 3/3 [==============================] - 1s 352ms/step - loss: 0.4980 - accuracy: 0.8413 - val_loss: 0.5110 - val_accuracy: 0.7708
# Epoch 20/30
# 3/3 [==============================] - 1s 356ms/step - loss: 0.4839 - accuracy: 0.8413 - val_loss: 0.5066 - val_accuracy: 0.7708
# Epoch 21/30
# 3/3 [==============================] - 1s 348ms/step - loss: 0.4697 - accuracy: 0.8360 - val_loss: 0.4969 - val_accuracy: 0.7917
# Epoch 22/30
# 3/3 [==============================] - 1s 337ms/step - loss: 0.4558 - accuracy: 0.8466 - val_loss: 0.4885 - val_accuracy: 0.7917
# Epoch 23/30
# 3/3 [==============================] - 1s 328ms/step - loss: 0.4460 - accuracy: 0.8571 - val_loss: 0.4873 - val_accuracy: 0.7292
# Epoch 24/30
# 3/3 [==============================] - 1s 353ms/step - loss: 0.4349 - accuracy: 0.8730 - val_loss: 0.4795 - val_accuracy: 0.7708
# Epoch 25/30
# 3/3 [==============================] - 1s 330ms/step - loss: 0
30
# 3/3 [==============================] - 1s 339ms/step - loss: 0.2822 - accuracy: 0.9579 - val_loss: 0.7954 - val_accuracy: 0.6383
# ----------------------Model resnet50----------------------
# acc mean = 0.74, std = 0.01, test_acc = [0.73, 0.73, 0.73, 0.75, 0.75]
# f1  mean = 0.71, std = 0.01, test_f1 = [0.7, 0.7, 0.7, 0.71, 0.72]
# ----------------------Model vgg16----------------------
# acc mean = 0.62, std = 0.06, test_acc = [0.65, 0.7, 0.57, 0.53, 0.63]
# f1  mean = 0.6, std = 0.07, test_f1 = [0.61, 0.7, 0.54, 0.51, 0.62]
# ----------------------Model vgg19----------------------
# acc mean = 0.61, std = 0.03, test_acc = [0.57, 0.67, 0.6, 0.6, 0.63]
# f1  mean = 0.58, std = 0.03, test_f1 = [0.54, 0.63, 0.57, 0.55, 0.6]
# ----------------------Model mobilenet----------------------
# acc mean = 0.71, std = 0.02, test_acc = [0.67, 0.73, 0.72, 0.7, 0.73]
# f1  mean = 0.68, std = 0.03, test_f1 = [0.64, 0.71, 0.7, 0.67, 0.7]
# ----------------------Model mobilenet_v2----------------------
# acc mean = 0.71, std = 0.03, test_acc = [0.68, 0.73, 0.67, 0.73, 0.75]
# f1  mean = 0.69, std = 0.03, test_f1 = [0.65, 0.71, 0.64, 0.7, 0.73]
# ----------------------Model efficientnet----------------------
# acc mean = 0.67, std = 0.01, test_acc = [0.68, 0.68, 0.65, 0.68, 0.65]
# f1  mean = 0.64, std = 0.01, test_f1 = [0.65, 0.66, 0.62, 0.65, 0.63]
# ----------------------Model inception_v3----------------------
# acc mean = 0.67, std = 0.02, test_acc = [0.7, 0.67, 0.63, 0.67, 0.68]
# f1  mean = 0.64, std = 0.03, test_f1 = [0.68, 0.64, 0.6, 0.62, 0.65]

# %%
# import
import numpy as np
import pandas as pd
import os.path
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt
import os

## label
# =========================
def class_2_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    else:
        label = "1"
    return label

# def class_4_type(root):
#     label = ""
#     if "0" in root:
#         label = "0"
#     elif "1" in root:
#         label = "1"
#     elif "2" in root:
#         label = "2"
#     else:
#         label = "3"
#     return label

# def class_2_type(root):
#     label = ""
#     if "雙踝" in root:
#         label = "0"
#     elif "三踝" in root:
#         label = "1"
#     return label

def class_3_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    elif "雙踝" in root:
        label = "1"
    elif "三踝" in root:
        label = "2"
    return label
# =========================


def load_path(path, class_count):
    dataset = []
    class_type = ''
    if class_count == 2:
        class_type = class_2_type
    elif class_count == 3:
        class_type = class_3_type  
    # elif class_count == 4:
    #     class_type = class_4_type     

    for root, dirs, files in os.walk(path):
        for file in files:
            label = class_type(root)
            # if label != "":
            dataset.append(
                            {   
                                'uuid': root.split("\\")[-1],
                                'label': label,
                                'image_path': os.path.join(root, file)
                            }
                        )

    return dataset

def train_cross_validation(image_dir, n_splits=5, class_count=2, maru_part=None,  chosen_model='resnet50'):


    ## load data and  labels
    # =========================
    labels = []
    filepaths = []
    data = load_path(image_dir, class_count)
    for row in data:
        labels.append(row['label'])
        filepaths.append(row['image_path'])

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    images = pd.concat([filepaths, labels], axis=1)
    # =========================
    

    ## front(AP+Mortise) or side(Lateral) 標籤
    # =========================
    part = ""
    if image_dir.split("//")[-1] == "front":
        part = "AP+Mortise"
    else:
        part = "Lateral"
    # =========================

    ## load chosen model
    # =========================
    if chosen_model == 'resnet50':
        preprocessing_function_chosen = tf.keras.applications.resnet50.preprocess_input
        pretrained_model_chosen = tf.keras.applications.resnet50.ResNet50
    # elif chosen_model == 'resnet152':
    #     preprocessing_function_chosen = tf.keras.applications.resnet152.preprocess_input
    #     pretrained_model_chosen = tf.keras.applications.resnet152.ResNet152
    elif chosen_model == 'vgg16':
        preprocessing_function_chosen = tf.keras.applications.vgg16.preprocess_input
        pretrained_model_chosen = tf.keras.applications.vgg16.VGG16
    elif chosen_model == 'vgg19':
        preprocessing_function_chosen = tf.keras.applications.vgg19.preprocess_input
        pretrained_model_chosen = tf.keras.applications.vgg19.VGG19
    elif chosen_model == 'mobilenet':
        preprocessing_function_chosen = tf.keras.applications.mobilenet.preprocess_input
        pretrained_model_chosen = tf.keras.applications.mobilenet.MobileNet
    elif chosen_model == 'mobilenet_v2':
        preprocessing_function_chosen = tf.keras.applications.mobilenet_v2.preprocess_input
        pretrained_model_chosen = tf.keras.applications.mobilenet_v2.MobileNetV2
    elif chosen_model == 'efficientnet':
        preprocessing_function_chosen = tf.keras.applications.efficientnet.preprocess_input
        pretrained_model_chosen = tf.keras.applications.efficientnet.EfficientNetB0
    elif chosen_model == 'inception_v3':
        preprocessing_function_chosen = tf.keras.applications.inception_v3.preprocess_input
        pretrained_model_chosen = tf.keras.applications.inception_v3.InceptionV3
    else:
        raise ValueError("Model name not recognized. Please choose a valid model.")




    # =========================

    ## to do: loss function
    # =========================
    # =========================


    print("-------Training " + part + "-------")
    train_df, test_df = train_test_split(images, train_size=0.8, shuffle=True, random_state=1, stratify=images['Label'])

    ## test  image
    # =========================
    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen)
    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )
    # =========================

    ## train model, k fold cross validation
    # ==================================================
    fold_no = 1
    test_acc = []
    test_f1 = []
    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
    for train_index, val_index in kfold.split(train_df, train_df['Label']):
        k_fold_train = train_df.iloc[train_index]
        k_fold_val = train_df.iloc[val_index]
        # print("K-fold training set label distribution:\n", k_fold_train['Label'].value_counts(normalize=True))
        # print("K-fold validation set label distribution:\n", k_fold_val['Label'].value_counts(normalize=True))
        
        ## train, validation image
        # =========================
        # 關閉翻轉
        train_generator = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,preprocessing_function=preprocessing_function_chosen)
        val_generator = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen)
        train_images = train_generator.flow_from_dataframe(
            dataframe=k_fold_train,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=True,
            seed=42
        )
        val_images = val_generator.flow_from_dataframe(
            dataframe=k_fold_val,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )
        # =========================
        
        ## load model
        # =========================
        if maru_part is not None:
            pretrained_model = tf.keras.models.load_model(maru_part)
        else:
            pretrained_model = pretrained_model_chosen(
                input_shape=(224, 224, 3),
                include_top=False,
                weights='imagenet',
                pooling='avg')

        pretrained_model.trainable = False

        inputs = pretrained_model.input
        x = tf.keras.layers.Dense(128, activation='relu', name='dense_128')(pretrained_model.output)
        x = tf.keras.layers.Dense(50, activation='relu', name='dense_50')(x)

        outputs = tf.keras.layers.Dense(class_count, activation='softmax', name='output_layer')(x)
        model = tf.keras.Model(inputs, outputs)
        # print(model.summary())
        # =========================

        ## compile and evaluate
        # =========================
        model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

       ## early stop 
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=5, restore_best_weights=True)
        model.fit(train_images, validation_data=val_images, callbacks=[early_stopping], epochs=30)
        
        ## no early stop
        # model.fit(train_images, validation_data=val_images, epochs=30)

        results = model.evaluate(test_images,  verbose=0)
        # =========================

        ## print each results
        # =========================
        test_acc.append(np.round(results[1], 2))
        pred = model.predict(test_images)
        predicted_labels = np.argmax(pred, axis=1)
        f1 = f1_score(test_images.labels, predicted_labels, average='macro')
        test_f1.append(np.round(f1, 2))
        fold_no += 1
        # =========================
    # ==================================================
        
    ## print  mean results
    # =========================
    acc_mean  = np.round(np.mean(test_acc), 2)
    acc_std = np.round(np.std(test_acc), 2)
    f1_mean  = np.round(np.mean(test_f1), 2)
    f1_std = np.round(np.std(test_f1), 2)
    # print(f"acc mean = {acc_mean}, std = {acc_std}")
    # print(test_acc)
    # print(f"f1  mean = {f1_mean}, std = {f1_std}")
    # print(test_f1)
    # =========================

    return {'acc_mean':acc_mean, 'acc_std':acc_std, 'test_acc':test_acc, 'f1_mean':f1_mean, 'f1_std':f1_std, 'test_f1':test_f1}


#####################################
# train_cross_validation: 訓練
#############
## image_dir: 影像來源
## class_count: 分幾個class
## n_splits: 幾折
## maru_part: 用maru哪個部位的模型pretrain
#############

# load_path: load image
#############
## path: 影像來源
## class_count: 分幾個class
## n_splits: 幾折
#############

# class_2_type, class_3_type: 種類標籤, 回傳label種類標籤, 回傳label

#####################################



## 訓練front or side
# =========================
# path = "E://data_bone//4-a+b_swift_cut_正確//side"
# path = "E://data_bone//4-a+b_swift_cut_正確//front"

# path = "E://data_bone//3-a+b_all_正確//side"
# path = "E://data_bone//3-a+b_all_正確//front"

# path = "E://data_bone//5-a+b_swift_cut_標準//side"
# path = "E://data_bone//5-a+b_swift_cut_標準//front"

# path = "E://data_bone//6-a+b_swift_cut_正確_5cluster//side"
# path = "E://data_bone//6-a+b_swift_cut_正確_5cluster//front"


# path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\side"
# path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\front"
# =========================

chosen_models = [
    'resnet50',
    # 'resnet152',
    'vgg16',
    'vgg19',
    'mobilenet',
    'mobilenet_v2',
    'efficientnet',
    'inception_v3'
]

results2 = []
print(len(chosen_models))
for i in range(len(chosen_models)):
    tmp = train_cross_validation(image_dir=path, class_count=3, chosen_model=chosen_models[i])
    results2.append(tmp)

for i in range(len(chosen_models)):
    print(f'----------------------Model {chosen_models[i]}----------------------')
    print(f"acc mean = {results2[i]['acc_mean']}, std = {results2[i]['acc_std']}, test_acc = {results2[i]['test_acc']}")
    print(f"f1  mean = {results2[i]['f1_mean']}, std = {results2[i]['f1_std']}, test_f1 = {results2[i]['test_f1']}")
# Out:
# 7
# -------Training Lateral-------
# Found 60 validated image filenames belonging to 3 classes.
# Found 189 validated image filenames belonging to 3 classes.
# Found 48 validated image filenames belonging to 3 classes.
# Epoch 1/30
# 3/3 [==============================] - 3s 541ms/step - loss: 1.4960 - accuracy: 0.2698 - val_loss: 1.2187 - val_accuracy: 0.1667
# Epoch 2/30
# 3/3 [==============================] - 1s 365ms/step - loss: 1.1595 - accuracy: 0.3280 - val_loss: 1.0997 - val_accuracy: 0.3958
# Epoch 3/30
# 3/3 [==============================] - 1s 349ms/step - loss: 1.1158 - accuracy: 0.4603 - val_loss: 1.0890 - val_accuracy: 0.4792
# Epoch 4/30
# 3/3 [==============================] - 1s 339ms/step - loss: 1.0824 - accuracy: 0.4550 - val_loss: 1.0367 - val_accuracy: 0.4792
# Epoch 5/30
# 3/3 [==============================] - 1s 317ms/step - loss: 1.0074 - accuracy: 0.4974 - val_loss: 0.9753 - val_accuracy: 0.5208
# Epoch 6/30
# 3/3 [==============================] - 1s 344ms/step - loss: 0.9394 - accuracy: 0.5661 - val_loss: 0.9479 - val_accuracy: 0.5833
# Epoch 7/30
# 3/3 [==============================] - 1s 336ms/step - loss: 0.8990 - accuracy: 0.6667 - val_loss: 0.9303 - val_accuracy: 0.6250
# Epoch 8/30
# 3/3 [==============================] - 1s 344ms/step - loss: 0.
30
# 3/3 [==============================] - 1s 347ms/step - loss: 0.9422 - accuracy: 0.6000 - val_loss: 0.9810 - val_accuracy: 0.4894
# Epoch 4/30
# 3/3 [==============================] - 1s 334ms/step - loss: 0.8800 - accuracy: 0.6368 - val_loss: 0.9496 - val_accuracy: 0.5319
# Epoch 5/30
# 3/3 [==============================] - 1s 339ms/step - loss: 0.8242 - accuracy: 0.6368 - val_loss: 0.9189 - val_accuracy: 0.5319
# Epoch 6/30
# 3/3 [==============================] - 1s 345ms/step - loss: 0.7738 - accuracy: 0.7000 - val_loss: 0.8985 - val_accuracy: 0.5532
# Epoch 7/30
# 3/3 [==============================] - 1s 337ms/step - loss: 0.7277 - accuracy: 0.7632 - val_loss: 0.8824 - val_accuracy: 0.5532
# Epoch 8/30
# 3/3 [==============================] - 1s 337ms/step - loss: 0.6874 - accuracy: 0.7737 - val_loss: 0.8690 - val_accuracy: 0.5745
# Epoch 9/30
# 3/3 [==============================] - 1s 345ms/step - loss: 0.6516 - accuracy: 0.7947 - val_loss: 0.8588 - val_accuracy: 0.5745
# Epoch 10/30
# 3/3 [==============================] - 1s 342ms/step - loss: 0.6178 - accuracy: 0.8211 - val_loss: 0.8541 - val_accuracy: 0.6170
# Epoch 11/30
# 3/3 [==============================] - 1s 337ms/step - loss: 0.5889 - accuracy: 0.8053 - val_loss: 0.8467 - val_accuracy: 0.5745
# Epoch 12/30
# 3/3 [==============================] - 1s 327ms/step - loss: 0.5594 - accuracy: 0.8526 - val_loss: 0.8243 - val_accuracy: 0.5957
# Epoch 13/30
# 3/3 [==============================] - 1s 342ms/step - loss: 0.5327 - accuracy: 0.8579 - val_loss: 0.8185 - val_accuracy: 0.5745
# Epoch 14/30
# 3/3 [==============================] - 1s 341ms/step - loss: 0.5077 - accuracy: 0.8684 - val_loss: 0.8198 - val_accuracy: 0.6383
# Epoch 15/30
# 3/3 [==============================] - 1s 339ms/step - loss: 0.4868 - accuracy: 0.8632 - val_loss: 0.8261 - val_accuracy: 0.6383
# Epoch 16/30
# 3/3 [==============================] - 1s 340ms/step - loss: 0.4638 - accuracy: 0.8737 - val_loss: 0.8126 - val_accuracy: 0.5957
# Epoch 17/30
# 3/3 [==============================] - 1s 356ms/step - loss: 0.4451 - accuracy: 0.8947 - val_loss: 0.8131 - val_accuracy: 0.5957
# Epoch 18/30
# 3/3 [==============================] - 1s 344ms/step - loss: 0.4252 - accuracy: 0.8895 - val_loss: 0.8126 - val_accuracy: 0.6170
# Epoch 19/30
# 3/3 [==============================] - 1s 341ms/step - loss: 0.4083 - accuracy: 0.8947 - val_loss: 0.8125 - val_accuracy: 0.5745
# ----------------------Model resnet50----------------------
# acc mean = 0.66, std = 0.08, test_acc = [0.63, 0.73, 0.57, 0.77, 0.58]
# f1  mean = 0.62, std = 0.08, test_f1 = [0.58, 0.7, 0.54, 0.74, 0.54]
# ----------------------Model vgg16----------------------
# acc mean = 0.51, std = 0.04, test_acc = [0.47, 0.53, 0.47, 0.58, 0.52]
# f1  mean = 0.46, std = 0.07, test_f1 = [0.4, 0.52, 0.37, 0.55, 0.44]
# ----------------------Model vgg19----------------------
# acc mean = 0.55, std = 0.07, test_acc = [0.5, 0.5, 0.47, 0.62, 0.65]
# f1  mean = 0.49, std = 0.11, test_f1 = [0.46, 0.44, 0.32, 0.6, 0.63]
# ----------------------Model mobilenet----------------------
# acc mean = 0.59, std = 0.04, test_acc = [0.62, 0.65, 0.58, 0.52, 0.58]
# f1  mean = 0.53, std = 0.08, test_f1 = [0.58, 0.61, 0.55, 0.37, 0.52]
# ----------------------Model mobilenet_v2----------------------
# acc mean = 0.61, std = 0.06, test_acc = [0.63, 0.7, 0.58, 0.63, 0.53]
# f1  mean = 0.56, std = 0.07, test_f1 = [0.57, 0.66, 0.55, 0.57, 0.45]
# ----------------------Model efficientnet----------------------
# acc mean = 0.58, std = 0.06, test_acc = [0.68, 0.53, 0.58, 0.52, 0.57]
# f1  mean = 0.51, std = 0.08, test_f1 = [0.66, 0.47, 0.5, 0.44, 0.48]
# ----------------------Model inception_v3----------------------
# acc mean = 0.63, std = 0.03, test_acc = [0.65, 0.62, 0.67, 0.58, 0.62]
# f1  mean = 0.59, std = 0.03, test_f1 = [0.62, 0.58, 0.63, 0.54, 0.57]

# %%
# import
import numpy as np
import pandas as pd
import os.path
# import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, StratifiedKFold
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt
import os

## label
# =========================
def class_2_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    else:
        label = "1"
    return label

# def class_4_type(root):
#     label = ""
#     if "0" in root:
#         label = "0"
#     elif "1" in root:
#         label = "1"
#     elif "2" in root:
#         label = "2"
#     else:
#         label = "3"
#     return label

# def class_2_type(root):
#     label = ""
#     if "雙踝" in root:
#         label = "0"
#     elif "三踝" in root:
#         label = "1"
#     return label

def class_3_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    elif "雙踝" in root:
        label = "1"
    elif "三踝" in root:
        label = "2"
    return label
# =========================


def load_path(path, class_count):
    dataset = []
    class_type = ''
    if class_count == 2:
        class_type = class_2_type
    elif class_count == 3:
        class_type = class_3_type  
    # elif class_count == 4:
    #     class_type = class_4_type     

    for root, dirs, files in os.walk(path):
        for file in files:
            label = class_type(root)
            # if label != "":
            dataset.append(
                            {   
                                'uuid': root.split("\\")[-1],
                                'label': label,
                                'image_path': os.path.join(root, file)
                            }
                        )

    return dataset

def train_cross_validation(image_dir, n_splits=5, class_count=2, maru_part=None,  chosen_model='resnet50'):


    ## load data and  labels
    # =========================
    labels = []
    filepaths = []
    data = load_path(image_dir, class_count)
    for row in data:
        labels.append(row['label'])
        filepaths.append(row['image_path'])

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    images = pd.concat([filepaths, labels], axis=1)
    # =========================
    

    ## front(AP+Mortise) or side(Lateral) 標籤
    # =========================
    part = ""
    if image_dir.split("//")[-1] == "front":
        part = "AP+Mortise"
    else:
        part = "Lateral"
    # =========================

    ## load chosen model
    # =========================
    if chosen_model == 'resnet50':
        preprocessing_function_chosen = tf.keras.applications.resnet50.preprocess_input
        pretrained_model_chosen = tf.keras.applications.resnet50.ResNet50
    # elif chosen_model == 'resnet152':
    #     preprocessing_function_chosen = tf.keras.applications.resnet152.preprocess_input
    #     pretrained_model_chosen = tf.keras.applications.resnet152.ResNet152
    elif chosen_model == 'vgg16':
        preprocessing_function_chosen = tf.keras.applications.vgg16.preprocess_input
        pretrained_model_chosen = tf.keras.applications.vgg16.VGG16
    elif chosen_model == 'vgg19':
        preprocessing_function_chosen = tf.keras.applications.vgg19.preprocess_input
        pretrained_model_chosen = tf.keras.applications.vgg19.VGG19
    elif chosen_model == 'mobilenet':
        preprocessing_function_chosen = tf.keras.applications.mobilenet.preprocess_input
        pretrained_model_chosen = tf.keras.applications.mobilenet.MobileNet
    elif chosen_model == 'mobilenet_v2':
        preprocessing_function_chosen = tf.keras.applications.mobilenet_v2.preprocess_input
        pretrained_model_chosen = tf.keras.applications.mobilenet_v2.MobileNetV2
    elif chosen_model == 'efficientnet':
        preprocessing_function_chosen = tf.keras.applications.efficientnet.preprocess_input
        pretrained_model_chosen = tf.keras.applications.efficientnet.EfficientNetB0
    elif chosen_model == 'inception_v3':
        preprocessing_function_chosen = tf.keras.applications.inception_v3.preprocess_input
        pretrained_model_chosen = tf.keras.applications.inception_v3.InceptionV3
    else:
        raise ValueError("Model name not recognized. Please choose a valid model.")




    # =========================

    ## to do: loss function
    # =========================
    # =========================


    print("-------Training " + part + "-------")
    train_df, test_df = train_test_split(images, train_size=0.8, shuffle=True, random_state=1, stratify=images['Label'])

    ## test  image
    # =========================
    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen)
    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )
    # =========================

    ## train model, k fold cross validation
    # ==================================================
    fold_no = 1
    test_acc = []
    test_f1 = []
    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
    for train_index, val_index in kfold.split(train_df, train_df['Label']):
        k_fold_train = train_df.iloc[train_index]
        k_fold_val = train_df.iloc[val_index]
        # print("K-fold training set label distribution:\n", k_fold_train['Label'].value_counts(normalize=True))
        # print("K-fold validation set label distribution:\n", k_fold_val['Label'].value_counts(normalize=True))
        
        ## train, validation image
        # =========================
        # 關閉翻轉
        train_generator = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False,preprocessing_function=preprocessing_function_chosen)
        val_generator = tf.keras.preprocessing.image.ImageDataGenerator(preprocessing_function=preprocessing_function_chosen)
        train_images = train_generator.flow_from_dataframe(
            dataframe=k_fold_train,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=True,
            seed=42
        )
        val_images = val_generator.flow_from_dataframe(
            dataframe=k_fold_val,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            seed=42
        )
        # =========================
        
        ## load model
        # =========================
        if maru_part is not None:
            pretrained_model = tf.keras.models.load_model(maru_part)
        else:
            pretrained_model = pretrained_model_chosen(
                input_shape=(224, 224, 3),
                include_top=False,
                weights='imagenet',
                pooling='avg')

        pretrained_model.trainable = False

        inputs = pretrained_model.input
        x = tf.keras.layers.Dense(128, activation='relu', name='dense_128')(pretrained_model.output)
        x = tf.keras.layers.Dense(50, activation='relu', name='dense_50')(x)

        outputs = tf.keras.layers.Dense(class_count, activation='softmax', name='output_layer')(x)
        model = tf.keras.Model(inputs, outputs)
        # print(model.summary())
        # =========================

        ## compile and evaluate
        # =========================
        model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

       ## early stop 
        early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True)
        model.fit(train_images, validation_data=val_images, callbacks=[early_stopping], epochs=30)
        
        ## no early stop
        # model.fit(train_images, validation_data=val_images, epochs=30)

        results = model.evaluate(test_images,  verbose=0)
        # =========================

        ## print each results
        # =========================
        test_acc.append(np.round(results[1], 2))
        pred = model.predict(test_images)
        predicted_labels = np.argmax(pred, axis=1)
        f1 = f1_score(test_images.labels, predicted_labels, average='macro')
        test_f1.append(np.round(f1, 2))
        fold_no += 1
        # =========================
    # ==================================================
        
    ## print  mean results
    # =========================
    acc_mean  = np.round(np.mean(test_acc), 2)
    acc_std = np.round(np.std(test_acc), 2)
    f1_mean  = np.round(np.mean(test_f1), 2)
    f1_std = np.round(np.std(test_f1), 2)
    # print(f"acc mean = {acc_mean}, std = {acc_std}")
    # print(test_acc)
    # print(f"f1  mean = {f1_mean}, std = {f1_std}")
    # print(test_f1)
    # =========================

    return {'acc_mean':acc_mean, 'acc_std':acc_std, 'test_acc':test_acc, 'f1_mean':f1_mean, 'f1_std':f1_std, 'test_f1':test_f1}


#####################################
# train_cross_validation: 訓練
#############
## image_dir: 影像來源
## class_count: 分幾個class
## n_splits: 幾折
## maru_part: 用maru哪個部位的模型pretrain
#############

# load_path: load image
#############
## path: 影像來源
## class_count: 分幾個class
## n_splits: 幾折
#############

# class_2_type, class_3_type: 種類標籤, 回傳label種類標籤, 回傳label

#####################################



## 訓練front or side
# =========================
# path = "E://data_bone//4-a+b_swift_cut_正確//side"
# path = "E://data_bone//4-a+b_swift_cut_正確//front"

# path = "E://data_bone//3-a+b_all_正確//side"
# path = "E://data_bone//3-a+b_all_正確//front"

# path = "E://data_bone//5-a+b_swift_cut_標準//side"
# path = "E://data_bone//5-a+b_swift_cut_標準//front"

# path = "E://data_bone//6-a+b_swift_cut_正確_5cluster//side"
# path = "E://data_bone//6-a+b_swift_cut_正確_5cluster//front"


# path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\side"
# path = "E:\\data_bone\\9-a+b_swift_cut_正確_V2\\front"
# =========================

chosen_models = [
    'resnet50',
    # 'resnet152',
    'vgg16',
    'vgg19',
    'mobilenet',
    'mobilenet_v2',
    'efficientnet',
    'inception_v3'
]

results3 = []
print(len(chosen_models))
for i in range(len(chosen_models)):
    tmp = train_cross_validation(image_dir=path, class_count=3, chosen_model=chosen_models[i])
    results3.append(tmp)

for i in range(len(chosen_models)):
    print(f'----------------------Model {chosen_models[i]}----------------------')
    print(f"acc mean = {results3[i]['acc_mean']}, std = {results3[i]['acc_std']}, test_acc = {results3[i]['test_acc']}")
    print(f"f1  mean = {results3[i]['f1_mean']}, std = {results3[i]['f1_std']}, test_f1 = {results3[i]['test_f1']}")
# Out:
# 7
# -------Training Lateral-------
# Found 60 validated image filenames belonging to 3 classes.
# Found 189 validated image filenames belonging to 3 classes.
# Found 48 validated image filenames belonging to 3 classes.
# Epoch 1/30
# 3/3 [==============================] - 3s 552ms/step - loss: 1.1706 - accuracy: 0.3757 - val_loss: 1.0721 - val_accuracy: 0.5208
# Epoch 2/30
# 3/3 [==============================] - 1s 363ms/step - loss: 1.0240 - accuracy: 0.5132 - val_loss: 1.0774 - val_accuracy: 0.5833
# Epoch 3/30
# 3/3 [==============================] - 1s 342ms/step - loss: 0.9822 - accuracy: 0.5979 - val_loss: 1.0111 - val_accuracy: 0.5833
# Epoch 4/30
# 3/3 [==============================] - 1s 349ms/step - loss: 0.9111 - accuracy: 0.6667 - val_loss: 0.9233 - val_accuracy: 0.6458
# Epoch 5/30
# 3/3 [==============================] - 1s 344ms/step - loss: 0.8458 - accuracy: 0.6402 - val_loss: 0.8655 - val_accuracy: 0.6458
# Epoch 6/30
# 3/3 [==============================] - 1s 336ms/step - loss: 0.8108 - accuracy: 0.6825 - val_loss: 0.8304 - val_accuracy: 0.6458
# Epoch 7/30
# 3/3 [==============================] - 1s 344ms/step - loss: 0.7787 - accuracy: 0.6878 - val_loss: 0.8014 - val_accuracy: 0.6458
# Epoch 8/30
# 3/3 [==============================] - 1s 325ms/step - loss: 0.7415 - accuracy: 0.7513 - val_loss: 0.7671 - val_accuracy: 0.7083
# Epoch 9/30
# 3/3 [==============================] - 1s 353ms/step - loss: 0.7024 - accuracy: 0.7354 - val_loss: 0.7382 - val_accuracy: 0.7708
# Epoch 10/30
# 3/3 [==============================] - 1s 305ms/step - loss: 0.6722 - accuracy: 0.7460 - val_loss: 0.7095 - val_accuracy: 0.7708
# Epoch 11/30
# 3/3 [==============================] - 1s 350ms/step - loss: 0.6424 - accuracy: 0.7566 - val_loss: 0.6727 - val_accuracy: 0.7917
# Epoch 12/30
# 3/3 [==============================] - 1s 378ms/step - loss: 0.6122 - accuracy: 0.8148 - val_loss: 0.6413 - val_accuracy: 0.7708
# Epoch 13/30
# 3/3 [==============================] - 1s 355ms/step - loss: 0.5859 - accuracy: 0.8148 - val_loss: 0.6235 - val_accuracy: 0.7708
# Epoch 14/30
# 3/3 [==============================] - 1s 368ms/step - loss: 0.5621 - accuracy: 0.8254 - val_loss: 0.6041 - val_accuracy: 0.7708
# Epoch 15/30
# 3/3 [==============================] - 1s 344ms/step - loss: 0.5374 - accuracy: 0.8624 - val_loss: 0.5942 - val_accuracy: 0.7708
# Epoch 16/30
# 3/3 [==============================] - 1s 354ms/step - loss: 0.5173 - accuracy: 0.8783 - val_loss: 0.5796 - val_accuracy: 0.7708
# Epoch 17/30
# 3/3 [==============================] - 1s 312ms/step - loss: 0.4965 - accuracy: 0.8677 - val_loss: 0.5597 - val_accuracy: 0.7500
# Epoch 18/30
# 3/3 [==============================] - 1s 342ms/step - loss: 0.4780 - accuracy: 0.8783 - val_loss: 0.5443 - val_accuracy: 0.7708
# Epoch 19/30
# 3/3 [==============================] - 1s 356ms/step - loss: 0.4615 - accuracy: 0.8889 - val_loss: 0.5354 - val_accuracy: 0.7500
# Epoch 20/30
# 3/3 [==============================] - 1s 329ms/step - loss: 0
30
# 3/3 [==============================] - 1s 350ms/step - loss: 0.5777 - accuracy: 0.8368 - val_loss: 0.7730 - val_accuracy: 0.6809
# Epoch 12/30
# 3/3 [==============================] - 1s 354ms/step - loss: 0.5479 - accuracy: 0.8579 - val_loss: 0.7665 - val_accuracy: 0.6809
# Epoch 13/30
# 3/3 [==============================] - 1s 343ms/step - loss: 0.5228 - accuracy: 0.8684 - val_loss: 0.7649 - val_accuracy: 0.6596
# Epoch 14/30
# 3/3 [==============================] - 1s 342ms/step - loss: 0.4971 - accuracy: 0.8842 - val_loss: 0.7628 - val_accuracy: 0.6596
# Epoch 15/30
# 3/3 [==============================] - 1s 350ms/step - loss: 0.4769 - accuracy: 0.8895 - val_loss: 0.7689 - val_accuracy: 0.6596
# Epoch 16/30
# 3/3 [==============================] - 1s 353ms/step - loss: 0.4546 - accuracy: 0.9000 - val_loss: 0.7591 - val_accuracy: 0.6596
# Epoch 17/30
# 3/3 [==============================] - 1s 341ms/step - loss: 0.4316 - accuracy: 0.9000 - val_loss: 0.7554 - val_accuracy: 0.6809
# Epoch 18/30
# 3/3 [==============================] - 1s 340ms/step - loss: 0.4158 - accuracy: 0.9105 - val_loss: 0.7576 - val_accuracy: 0.6596
# Epoch 19/30
# 3/3 [==============================] - 1s 352ms/step - loss: 0.3949 - accuracy: 0.9053 - val_loss: 0.7732 - val_accuracy: 0.6383
# Epoch 20/30
# 3/3 [==============================] - 1s 349ms/step - loss: 0.3792 - accuracy: 0.9000 - val_loss: 0.7800 - val_accuracy: 0.6596
# Epoch 21/30
# 3/3 [==============================] - 1s 344ms/step - loss: 0.3643 - accuracy: 0.9105 - val_loss: 0.7708 - val_accuracy: 0.6596
# ----------------------Model resnet50----------------------
# acc mean = 0.71, std = 0.05, test_acc = [0.73, 0.73, 0.7, 0.62, 0.78]
# f1  mean = 0.68, std = 0.06, test_f1 = [0.7, 0.7, 0.66, 0.57, 0.76]
# ----------------------Model vgg16----------------------
# acc mean = 0.54, std = 0.04, test_acc = [0.58, 0.58, 0.55, 0.5, 0.5]
# f1  mean = 0.5, std = 0.06, test_f1 = [0.56, 0.56, 0.49, 0.41, 0.46]
# ----------------------Model vgg19----------------------
# acc mean = 0.51, std = 0.1, test_acc = [0.65, 0.45, 0.58, 0.37, 0.5]
# f1  mean = 0.45, std = 0.13, test_f1 = [0.6, 0.38, 0.56, 0.24, 0.46]
# ----------------------Model mobilenet----------------------
# acc mean = 0.69, std = 0.04, test_acc = [0.68, 0.7, 0.75, 0.65, 0.65]
# f1  mean = 0.65, std = 0.05, test_f1 = [0.65, 0.67, 0.73, 0.59, 0.59]
# ----------------------Model mobilenet_v2----------------------
# acc mean = 0.67, std = 0.06, test_acc = [0.68, 0.68, 0.55, 0.72, 0.7]
# f1  mean = 0.63, std = 0.08, test_f1 = [0.66, 0.66, 0.46, 0.69, 0.67]
# ----------------------Model efficientnet----------------------
# acc mean = 0.65, std = 0.04, test_acc = [0.7, 0.65, 0.6, 0.62, 0.67]
# f1  mean = 0.61, std = 0.05, test_f1 = [0.67, 0.62, 0.54, 0.58, 0.64]
# ----------------------Model inception_v3----------------------
# acc mean = 0.64, std = 0.06, test_acc = [0.62, 0.67, 0.63, 0.55, 0.73]
# f1  mean = 0.6, std = 0.07, test_f1 = [0.58, 0.63, 0.59, 0.5, 0.71]
