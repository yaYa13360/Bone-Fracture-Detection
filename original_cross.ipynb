# %%
import os
import os.path

import tensorflow as tf
import pandas as pd
import numpy as np

from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, f1_score
import matplotlib.pyplot as plt

def class_2_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    else:
        label = "1"
    return label


# def class_2_type(root):
#     label = ""
#     if "雙踝" in root:
#         label = "0"
#     elif "三踝" in root:
#         label = "1"
#     return label


def class_3_type(root):
    label = ""
    if "正常" in root:
        label = "0"
    elif "雙踝" in root:
        label = "1"
    elif "三踝" in root:
        label = "2"
    return label


def load_path(path, class_count):
    dataset = []
    class_type = ''
    if class_count == 2:
        class_type = class_2_type
    elif class_count == 3:
        class_type = class_3_type   

    for root, dirs, files in os.walk(path):
        for file in files:
            if file.lower().endswith('.jpg'):
                label = class_type(root)
                # if label != "":
                dataset.append(
                                {   
                                    'uuid': root.split("\\")[-1],
                                    'label': label,
                                    'image_path': os.path.join(root, file)
                                }
                            )

    return dataset

# %%
def train_original_cross(image_dir, n_splits=5, class_count=2, maru_part=None,  chosen_model='resnet50'):


    ## load data and  labels
    # =========================
    labels = []
    filepaths = []
    data = load_path(image_dir, class_count)
    for row in data:
        labels.append(row['label'])
        filepaths.append(row['image_path'])

    filepaths = pd.Series(filepaths, name='Filepath').astype(str)
    labels = pd.Series(labels, name='Label')

    images = pd.concat([filepaths, labels], axis=1)
    # =========================


    ## define common params, same as transfer
    # =========================
    comon_params={
            ## fully CV layer
            "include_top": True,
            ## no pretrain 
            "weights": None,
            "input_shape": (224, 224, 3),
            "pooling": 'avg',
            "classes": class_count,
            "classifier_activation": 'softmax'
    }
    # =========================
    


    ## load chosen model
    # =========================
    if chosen_model == 'resnet50':
        model = tf.keras.applications.ResNet50(**comon_params)
    # elif chosen_model == 'resnet152':
    #   model = tf.keras.applications.ResNet152(**comon_params)
    elif chosen_model == 'vgg16':
        model = tf.keras.applications.VGG16(**comon_params)
    elif chosen_model == 'vgg19':
        model = tf.keras.applications.VGG19(**comon_params)
    elif chosen_model == 'mobilenet':
        model = tf.keras.applications.VGG19(**comon_params)
    elif chosen_model == 'mobilenet_v2':
        model = tf.keras.applications.VGG19(**comon_params)
    elif chosen_model == 'efficientnet':
        model = tf.keras.applications.VGG19(**comon_params)
    elif chosen_model == 'inception_v3':
        model = tf.keras.applications.VGG19(**comon_params)
    else:
        raise ValueError("Model name not recognized. Please choose a valid model.")
    # =========================

    train_df, test_df = train_test_split(images, train_size=0.8, shuffle=True, random_state=1, stratify=images['Label'])

    ## test  image
    # =========================
    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False)
    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False,
        # 補preprocess_input的正規化
        rescale=1./255
    )
    # =========================

    ## train model, k fold cross validation
    # ==================================================
    fold_no = 1
    test_acc = []
    test_f1 = []
    print("-------Training{}, fold = {} -------".format(chosen_model, fold_no))
    kfold = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1)
    for train_index, val_index in kfold.split(train_df, train_df['Label']):
        k_fold_train = train_df.iloc[train_index]
        k_fold_val = train_df.iloc[val_index]
        # print("K-fold training set label distribution:\n", k_fold_train['Label'].value_counts(normalize=True))
        # print("K-fold validation set label distribution:\n", k_fold_val['Label'].value_counts(normalize=True))
        
        ## train, validation image
        # =========================
        # 關閉翻轉
        train_generator = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False)
        val_generator = tf.keras.preprocessing.image.ImageDataGenerator(horizontal_flip=False)
        train_images = train_generator.flow_from_dataframe(
            dataframe=k_fold_train,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=True,
            rescale=1./255,
            seed=42
        )
        val_images = val_generator.flow_from_dataframe(
            dataframe=k_fold_val,
            x_col='Filepath',
            y_col='Label',
            target_size=(224, 224),
            color_mode='rgb',
            class_mode='categorical',
            batch_size=64,
            shuffle=False,
            rescale=1./255,
            seed=42
        )
        # =========================
        
        ## load model
        # =========================
        # print(model.summary())
        # =========================

        ## compile and evaluate
        # =========================
        model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

        ## early stop 
        # callbacks = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
        
        ## no early stop
        model.fit(train_images, validation_data=val_images, epochs=30)

        results = model.evaluate(test_images,  verbose=0)
        # =========================

        ## print each results
        # =========================
        test_acc.append(np.round(results[1], 2))
        pred = model.predict(test_images)
        predicted_labels = np.argmax(pred, axis=1)
        f1 = f1_score(test_images.labels, predicted_labels, average='macro')
        test_f1.append(np.round(f1, 2))
        fold_no += 1
        # =========================
    # ==================================================
        
    ## print  mean results
    # =========================
    acc_mean  = np.round(np.mean(test_acc), 2)
    acc_std = np.round(np.std(test_acc), 2)
    f1_mean  = np.round(np.mean(test_f1), 2)
    f1_std = np.round(np.std(test_f1), 2)
    # print(f"acc mean = {acc_mean}, std = {acc_std}")
    # print(test_acc)
    # print(f"f1  mean = {f1_mean}, std = {f1_std}")
    # print(test_f1)
    # =========================

    return {'acc_mean':acc_mean, 'acc_std':acc_std, 'test_acc':test_acc, 'f1_mean':f1_mean, 'f1_std':f1_std, 'test_f1':test_f1}


#####################################
# train_cross_validation: 訓練
#############
## image_dir: 影像來源
## class_count: 分幾個class
## n_splits: 幾折
## maru_part: 用maru哪個部位的模型pretrain
#############

# load_path: load image
#############
## path: 影像來源
## class_count: 分幾個class
## n_splits: 幾折
#############

# class_2_type, class_3_type: 種類標籤, 回傳label種類標籤, 回傳label

#####################################



## 訓練front or side
# =========================
# path = "E://data_bone//4-a+b_swift_cut_正確//side"
# path = "E://data_bone//4-a+b_swift_cut_正確//front"

path = "E://data_bone//3-a+b_all_正確//side"
# path = "E://data_bone//3-a+b_all_正確//front"

# path = "E://data_bone//5-a+b_swift_cut_標準//front"
# path = "E://data_bone//5-a+b_swift_cut_標準//side"

# =========================

chosen_models = [
    'resnet50',
    # 'resnet152',
    'vgg16',
    'vgg19',
    'mobilenet',
    'mobilenet_v2',
    'efficientnet',
    'inception_v3'
]

results = []
for i in range(len(chosen_models)):
    tmp = train_original_cross(image_dir=path, class_count=2, chosen_model=chosen_models[i])
    results.append(tmp)

for i in range(len(chosen_models)):
    print(f'----------------------Model {chosen_models[i]}----------------------')
    print(f"acc mean = {results[i]['acc_mean']}, std = {results[i]['acc_std']}, test_acc = {results[i]['test_acc']}")
    print(f"f1  mean = {results[i]['f1_mean']}, std = {results[i]['f1_std']}, test_f1 = {results[i]['test_f1']}")
# Out:
# Found 84 validated image filenames belonging to 2 classes.
# -------Trainingresnet50, fold = 1 -------
# Found 267 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Epoch 1/30
# 5/5 [==============================] - 5s
30
# 5/5 [==============================] - 3s 648ms/step - loss: 0.0397 - accuracy: 0.9813 - val_loss: 0.3600 - val_accuracy: 0.8806
# Epoch 3/30
# 5/5 [==============================] - 3s 595ms/step - loss: 0.0871 - accuracy: 0.9700 - val_loss: 0.8539 - val_accuracy: 0.7612
# Epoch 4/30
# 5/5 [==============================] - 3s 627ms/step - loss: 0.0662 - accuracy: 0.9738 - val_loss: 0.2536 - val_accuracy: 0.8806
# Epoch 5/30
# 5/5 [==============================] - 3s 673ms/step - loss: 0.0927 - accuracy: 0.9738 - val_loss: 0.3874 - val_accuracy: 0.8358
# Epoch 6/30
# 5/5 [==============================] - 3s 659ms/step - loss: 0.0484 - accuracy: 0.9738 - val_loss: 1.8045 - val_accuracy: 0.6418
# Epoch 7/30
# 5/5 [==============================] - 3s 628ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 2.6046 - val_accuracy: 0.6269
# Epoch 8/30
# 5/5 [==============================] - 4s 849ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 2.5364 - val_accuracy: 0.6567
# Epoch 9/30
# 5/5 [==============================] - 4s 671ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 2.2641 - val_accuracy: 0.6716
# Epoch 10/30
# 5/5 [==============================] - 3s 630ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.0274 - val_accuracy: 0.7015
# Epoch 11/30
# 5/5 [==============================] - 4s 692ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.9990 - val_accuracy: 0.7015
# Epoch 12/30
# 5/5 [==============================] - 3s 662ms/step - loss: 5.5114e-04 - accuracy: 1.0000 - val_loss: 1.8695 - val_accuracy: 0.6866
# Epoch 13/30
# 5/5 [==============================] - 3s 806ms/step - loss: 2.0342e-04 - accuracy: 1.0000 - val_loss: 1.6990 - val_accuracy: 0.7015
# Epoch 14/30
# 5/5 [==============================] - 3s 783ms/step - loss: 2.1105e-04 - accuracy: 1.0000 - val_loss: 1.5670 - val_accuracy: 0.7015
# Epoch 15/30
# 5/5 [==============================] - 4s 843ms/step - loss: 1.5266e-04 - accuracy: 1.0000 - val_loss: 1.4441 - val_accuracy: 0.7164
# Epoch 16/30
# 5/5 [==============================] - 3s 647ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.1854 - val_accuracy: 0.7164
# Epoch 17/30
# 5/5 [==============================] - 3s 805ms/step - loss: 0.0196 - accuracy: 0.9888 - val_loss: 2.5057 - val_accuracy: 0.6567
# Epoch 18/30
# 5/5 [==============================] - 4s 696ms/step - loss: 0.0309 - accuracy: 0.9888 - val_loss: 3.4090 - val_accuracy: 0.6119
# Epoch 19/30
# 5/5 [==============================] - 3s 645ms/step - loss: 0.0197 - accuracy: 0.9888 - val_loss: 1.6244 - val_accuracy: 0.6866
# Epoch 20/30
# 5/5 [==============================] - 4s 843ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.6732 - val_accuracy: 0.6418
# Epoch 21/30
# 5/5 [==============================] - 3s 664ms/step - loss: 0.0206 - accuracy: 0.9925 - val_loss: 1.8443 - val_accuracy: 0.6716
# Epoch 22/30
# 5/5 [==============================] - 4s 652ms/step - loss: 0.0214 - accuracy: 0.9963 - val_loss: 0.8389 - val_accuracy: 0.7164
# Epoch 23/30
# 5/5 [==============================] - 3s 671ms/step - loss: 0.0769 - accuracy: 0.9700 - val_loss: 1.4734 - val_accuracy: 0.6866
# Epoch 24/30
# 5/5 [==============================] - 4s 709ms/step - loss: 0.0158 - accuracy: 0.9963 - val_loss: 4.4100 - val_accuracy: 0.6119
# Epoch 25/30
# 5/5 [==============================] - 3s 648ms/step - loss: 0.0088 - accuracy: 0.9963 - val_loss: 8.6448 - val_accuracy: 0.6119
# Epoch 26/30
# 5/5 [==============================] - 4s 700ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 5.2001 - val_accuracy: 0.6119
# Epoch 27/30
# 5/5 [==============================] - 3s 628ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 3.2291 - val_accuracy: 0.6567
# Epoch 28/30
# 5/5 [==============================] - 3s 653ms/step - loss: 0.0347 - accuracy: 0.9963 - val_loss: 7.9272 - val_accuracy: 0.6119
# Epoch 29/30
# 5/5 [==============================] - 4s 670ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 10.3457 - val_accuracy: 0.6119
# Epoch 30/30
# 5/5 [==============================] - 3s 806ms/step - loss: 0.0354 - accuracy: 0.9813 - val_loss: 6.1112 - val_accuracy: 0.6119
# Found 268 validated image filenames belonging to 2 classes.
# Found 66 validated image filenames belonging to 2 classes.
# Epoch 1/30
# 5/5 [==============================] - 8s 960ms/step - loss: 0.1911 - accuracy: 0.9552 - val_loss: 6.2338 - val_accuracy: 0.6212
# Epoch 2/30
# 5/5 [==============================] - 3s 648ms/step - loss: 0.0417 - accuracy: 0.9888 - val_loss: 6.0108 - val_accuracy: 0.6212
# Epoch 3/30
# 5/5 [==============================] - 3s 626ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 1.9477 - val_accuracy: 0.7121
# Epoch 4/30
# 5/5 [==============================] - 4s 655ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 2.6659 - val_accuracy: 0.6970
# Epoch 5/30
# 5/5 [==============================] - 3s 648ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 2.5439 - val_accuracy: 0.6970
# Epoch 6/30
# 5/5 [==============================] - 3s 648ms/step - loss: 0.0046 - accuracy: 0.9963 - val_loss: 0.0185 - val_accuracy: 1.0000
# Epoch 7/30
# 5/5 [==============================] - 3s 637ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.6450 - val_accuracy: 0.6667
# Epoch 8/30
# 5/5 [==============================] - 3s 823ms/step - loss: 0.0236 - accuracy: 0.9925 - val_loss: 0.0220 - val_accuracy: 1.0000
# Epoch 9/30
# 5/5 [==============================] - 4s 679ms/step - loss: 0.0195 - accuracy: 0.9925 - val_loss: 0.4707 - val_accuracy: 0.8636
# Epoch 10/30
# 5/5 [==============================] - 3s 665ms/step - loss: 0.0075 - accuracy: 0.9963 - val_loss: 1.5335 - val_accuracy: 0.7576
# Epoch 11/30
# 5/5 [==============================] - 3s 648ms/step - loss: 0.0140 - accuracy: 0.9963 - val_loss: 0.6088 - val_accuracy: 0.8485
# Epoch 12/30
# 5/5 [==============================] - 3s 658ms/step - loss: 0.0495 - accuracy: 0.9851 - val_loss: 0.2380 - val_accuracy: 0.9545
# Epoch 13/30
# 5/5 [==============================] - 4s 701ms/step - loss: 0.0192 - accuracy: 0.9963 - val_loss: 0.5200 - val_accuracy: 0.8485
# Epoch 14/30
# 5/5 [==============================] - 3s 627ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.6120 - val_accuracy: 0.8333
# Epoch 15/30
# 5/5 [==============================] - 3s 541ms/step - loss: 0.0278 - accuracy: 0.9925 - val_loss: 0.2599 - val_accuracy: 0.9242
# Epoch 16/30
# 5/5 [==============================] - 3s 765ms/step - loss: 0.0761 - accuracy: 0.9813 - val_loss: 2.3027 - val_accuracy: 0.6970
# Epoch 17/30
# 5/5 [==============================] - 3s 625ms/step - loss: 0.0972 - accuracy: 0.9664 - val_loss: 6.1276 - val_accuracy: 0.6364
# Epoch 18/30
# 5/5 [==============================] - 3s 602ms/step - loss: 0.0144 - accuracy: 0.9963 - val_loss: 6.3359 - val_accuracy: 0.6364
# Epoch 19/30
# 5/5 [==============================] - 3s 615ms/step - loss: 0.0369 - accuracy: 0.9851 - val_loss: 17.2122 - val_accuracy: 0.6212
# Epoch 20/30
# 5/5 [==============================] - 3s 592ms/step - loss: 0.1490 - accuracy: 0.9664 - val_loss: 12.9095 - val_accuracy: 0.6212
# Epoch 21/30
# 5/5 [==============================] - 3s 634ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 7.8616 - val_accuracy: 0.6212
# Epoch 22/30
# 5/5 [==============================] - 3s 627ms/step - loss: 0.0303 - accuracy: 0.9813 - val_loss: 3.6871 - val_accuracy: 0.6970
# Epoch 23/30
# 5/5 [==============================] - 3s 739ms/step - loss: 0.0166 - accuracy: 0.9925 - val_loss: 1.1212 - val_accuracy: 0.8333
# Epoch 24/30
# 5/5 [==============================] - 3s 628ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.2224 - val_accuracy: 0.9545
# Epoch 25/30
# 5/5 [==============================] - 3s 591ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9697
# Epoch 26/30
# 5/5 [==============================] - 3s 750ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9848
# Epoch 27/30
# 5/5 [==============================] - 3s 615ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0244 - val_accuracy: 0.
- accuracy: 1.0000 - val_loss: 0.0787 - val_accuracy: 0.9848
# Epoch 16/30
# 5/5 [==============================] - 3s 664ms/step - loss: 1.8081e-06 - accuracy: 1.0000 - val_loss: 0.0785 - val_accuracy: 0.9848
# Epoch 17/30
# 5/5 [==============================] - 4s 865ms/step - loss: 1.4892e-06 - accuracy: 1.0000 - val_loss: 0.0788 - val_accuracy: 0.9848
# Epoch 18/30
# 5/5 [==============================] - 4s 670ms/step - loss: 1.2646e-06 - accuracy: 1.0000 - val_loss: 0.0792 - val_accuracy: 0.9848
# Epoch 19/30
# 5/5 [==============================] - 3s 654ms/step - loss: 1.1729e-06 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9848
# Epoch 20/30
# 5/5 [==============================] - 3s 617ms/step - loss: 1.0631e-06 - accuracy: 1.0000 - val_loss: 0.0803 - val_accuracy: 0.9848
# Epoch 21/30
# 5/5 [==============================] - 3s 633ms/step - loss: 9.8435e-07 - accuracy: 1.0000 - val_loss: 0.0807 - val_accuracy: 0.9848
# Epoch 22/30
# 5/5 [==============================] - 3s 638ms/step - loss: 9.4432e-07 - accuracy: 1.0000 - val_loss: 0.0811 - val_accuracy: 0.9848
# Epoch 23/30
# 5/5 [==============================] - 3s 729ms/step - loss: 8.8827e-07 - accuracy: 1.0000 - val_loss: 0.0813 - val_accuracy: 0.9848
# Epoch 24/30
# 5/5 [==============================] - 4s 669ms/step - loss: 8.5580e-07 - accuracy: 1.0000 - val_loss: 0.0815 - val_accuracy: 0.9848
# Epoch 25/30
# 5/5 [==============================] - 3s 626ms/step - loss: 8.1755e-07 - accuracy: 1.0000 - val_loss: 0.0817 - val_accuracy: 0.9848
# Epoch 26/30
# 5/5 [==============================] - 3s 629ms/step - loss: 7.8731e-07 - accuracy: 1.0000 - val_loss: 0.0819 - val_accuracy: 0.9848
# Epoch 27/30
# 5/5 [==============================] - 3s 648ms/step - loss: 7.5973e-07 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9848
# Epoch 28/30
# 5/5 [==============================] - 3s 835ms/step - loss: 7.4105e-07 - accuracy: 1.0000 - val_loss: 0.0819 - val_accuracy: 0.9848
# Epoch 29/30
# 5/5 [==============================] - 3s 642ms/step - loss: 7.1614e-07 - accuracy: 1.0000 - val_loss: 0.0820 - val_accuracy: 0.9848
# Epoch 30/30
# 5/5 [==============================] - 4s 696ms/step - loss: 6.9657e-07 - accuracy: 1.0000 - val_loss: 0.0821 - val_accuracy: 0.9848
# Found 84 validated image filenames belonging to 2 classes.
# -------Trainingmobilenet, fold = 1 -------
# Found 267 validated image filenames belonging to 2 classes.
# Found 67 validated image filenames belonging to 2 classes.
# Epoch 1/30
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29376\3692934917.py in <module>
#     211 results = []
#     212 for i in range(len(chosen_models)):
# --> 213     tmp = train_original_cross(image_dir=path, class_count=2, chosen_model=chosen_models[i])
#     214     results.append(tmp)
#     215
#
# ~\AppData\Local\Temp\ipykernel_29376\3692934917.py in train_original_cross(image_dir, n_splits, class_count, maru_part, chosen_model)
#     132
#     133         ## no early stop
# --> 134         model.fit(train_images, validation_data=val_images, epochs=30)
#     135
#     136         results = model.evaluate(test_images,  verbose=0)
#
# d:\anaconda3\envs\bone_20240719\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# d:\anaconda3\envs\bone_20240719\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# d:\anaconda3\envs\bone_20240719\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     948         # Lifting succeeded, so variables are initialized and we can run the
#     949         # stateless function.
# --> 950         return self._stateless_fn(*args, **kwds)
#     951     else:
#     952       _, _, _, filtered_flat_args = \
#
# d:\anaconda3\envs\bone_20240719\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# d:\anaconda3\envs\bone_20240719\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# d:\anaconda3\envs\bone_20240719\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# d:\anaconda3\envs\bone_20240719\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# ResourceExhaustedError:  OOM when allocating tensor with shape[25088,4096] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[node gradient_tape/vgg19/fc1/MatMul_1 (defined at C:\Users\ya389\AppData\Local\Temp\ipykernel_29376\3692934917.py:134) ]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info. This isn't available when running in Eager mode.
#  [Op:__inference_train_function_392672]
#
# Function call stack:
# train_function

# %%
print(path)
for i in range(len(chosen_models)):
    print(f'----------------------Model {chosen_models[i]}----------------------')
    print(f"acc mean = {results[i]['acc_mean']}, std = {results[i]['acc_std']}, test_acc = {results[i]['test_acc']}")
    print(f"f1  mean = {results[i]['f1_mean']}, std = {results[i]['f1_std']}, test_f1 = {results[i]['test_f1']}")

# %%
# print(path)
# for i in range(len(chosen_models)):
#     print(f'----------------------Model {chosen_models[i]}----------------------')
#     print(f"acc mean = {results[i]['acc_mean']}, std = {results[i]['acc_std']}, test_acc = {results[i]['test_acc']}")
#     print(f"f1  mean = {results[i]['f1_mean']}, std = {results[i]['f1_std']}, test_f1 = {results[i]['test_f1']}")
